# %% [markdown]
# ```
# ---
# title: API Review with Foursquare API
# type:  lesson + lab + demo
# duration: "1:25"
# creator:
#     name: David Yerrington
#     city: SF
# ---
# ```
# <img src="https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png" style="float: left; margin: 10px">
#
# #  API Demo / Lab + NLP
# Week 8 | 3.3
#
#
# <img src="https://snag.gy/RNAEgP.jpg" width="600">
#
# Can we correctly identify which of these two old men tweeted what?

# %% [markdown]
# ## (5 mins) Opening
#
# Today we are going to attempt to classify wether a tweet comes from Trump, or Sanders.  We are going to:
#
# - Create a developer account on Twitter
# - Create a method to pull a list of tweets from the Twitter API
# - Perform proper preprocessing on our text
# - Engineer sentiment feature in our dataset using TextBlob
# - Explore supervised classification techniques

# %% [markdown]
# ## Twitter API Developer Registration
#
# If you haven't registered a Twitter account yet, this is a requirement in order to have a "developer" account.
#
# [Twitter Rest API](https://dev.twitter.com/rest/public)

# %% [markdown]
# ## Create an "App"
#
# ![](https://snag.gy/HPBQbJ.jpg)
#
# We now will now go to Twitter and register an "app" [apps.twitter.com](https://apps.twitter.com/), just like we did for Foursquare.  After we set up our app, we will only need to reference the cooresponding keys Twitter generates for our app.  These are the keys that we will use with our application to communicate with the Twitter API.

# %% [markdown]
# ## Install Python Twitter API library
#
# Someone was nice enough to build a nice libary for us in Python that we only need to plug in our keys and start collecting data with.  The library we will be using is provided by [Python Twitter Tools](http://mike.verdone.ca/twitter/).
#
# To install it, just run the next frame (there is no conda package).

# %%
# !pip install twitter python-twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.17.1-py2.py3-none-any.whl (55kB)
# Collecting python-twitter
#   Downloading python-twitter-3.1.tar.gz (80kB)
# Collecting future (from python-twitter)
#   Downloading future-0.15.2.tar.gz (1.6MB)
# Requirement already satisfied (use --upgrade to upgrade): requests in c:\anaconda2\lib\site-packages (from python-twitter)
# Collecting requests-oauthlib (from python-twitter)
#   Downloading requests_oauthlib-0.6.1-py2.py3-none-any.whl
# Collecting oauthlib>=0.6.2 (from requests-oauthlib->python-twitter)
#   Downloading oauthlib-1.1.2.tar.gz (111kB)
# Building wheels for collected packages: python-twitter, future, oauthlib
#   Running setup.py bdist_wheel for python-twitter: started
#   Running setup.py bdist_wheel for python-twitter: finished with status 'done'
#   Stored in directory: C:\Users\Owner\AppData\Local\pip\Cache\wheels\22\1e\2e\506871fa7dc610616948e70812d5e2518cd89c13f757b98f6c
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\Owner\AppData\Local\pip\Cache\wheels\11\c5\d2\ad287de27d0f0d646f119dcffb921f4e63df128f28ab0a1bda
#   Running setup.py bdist_wheel for oauthlib: started
#   Running setup.py bdist_wheel for oauthlib: finished with status 'done'
#   Stored in directory: C:\Users\Owner\AppData\Local\pip\Cache\wheels\e6\be\43\e4a2ca8cb9c78fbd9b5b14b96cb7a5cc43f36bc11af5dfac5b
# Successfully built python-twitter future oauthlib
# Installing collected packages: twitter, future, oauthlib, requests-oauthlib, python-twitter
# Successfully installed future-0.15.2 oauthlib-1.1.2 python-twitter-3.1 requests-oauthlib-0.6.1 twitter-1.17.1

# %% [markdown]
# ## Some Boring Twitter Rules
#
# Twitter says they will rate limit your requests:
#
# >When using application-only authentication, rate limits are determined globally for the entire application. If a method allows for 15 requests per rate limit window, then it allows you to make 15 requests per window — on behalf of your application. This limit is considered completely separately from per-user limits. https://dev.twitter.com/rest/public/rate-limiting
#
# Here's a quick overview of what Twitter says are "the rulez":
#
# ![](https://snag.gy/yJ6vIH.jpg)

# %% [markdown]
# ## About those Keys: OAuth Review
#
# ![](https://g.twimg.com/dev/documentation/image/appauth_0.png)

# %% [markdown]
# ## What's going on here?  Take a minute..

# %% [markdown]
# ## Our Application Keys
#
# Take note of our application keys that we will be using with our little application that will be connecting to Twitter and mining Tweets from the official Bernie Sanders and Donald Trump twitter accounts.
#
# ![](https://snag.gy/H1djQK.jpg)

# %% [markdown]
# ## Tweet Miner Class Setup
#
# The following code is meant to get us up and running with connectivity to twitter, and the ability to make requests and easily transform the JSON responses to DataFrames.  We will be using object oriented Python in order to organize our code.  We may go into review since this was a topic we covered earlier in the class but we can review it during the lab for those who want to know more about it.
#
#
# > "request_limit" is used in this class to limit the number of tweets that are pulled per instance request.  Setting it to something lower until you've worked the bugs out of your request, and captured the data you want, is essential to avoiding any rate limit blocks.
#
# #### Key Setup
#
# - **consumer_key** - Find this in your app page under the "Keys and Access Tokens"
# - **consumer_secret** - Right under **consumer_key** in the "Keys and Access Tokens" tab
# - **access_token_key** - You will need to click the "generate tokens" button to get this
# - **access_token_secret** - Also available after "generate tokens" is pressed

# %%
import twitter, re, datetime, pandas as pd

class twitterminer():

    request_limit   =   200    
    api             =   False
    data            =   []
    
    twitter_keys = {
        'consumer_key':        'OXSTNZHW26RkuPblPgHMq8POu',
        'consumer_secret':     'upotD5Zv9ez8CpeW2fBgcEV6Jfub3vPOe3hV4eH1V1ZQA2bXpP',
        'access_token_key':    '3124576252-gv8wG2f8Mk3O40ix8JZ2d0YHbhM6nancRcbiAwa',
        'access_token_secret': 'uIoS6FyW73ENToGncyqJA79yjgRq0YSp5O52cGmaCQJx5'
    }
    
    def __init__(self,  request_limit = 200):
        
        self.request_limit = request_limit
        
        # This sets the twitter API object for use internall within the class
        self.set_api()
        
    def set_api(self):
        
        self.api = twitter.Api(
            consumer_key         =   self.twitter_keys['consumer_key'],
            consumer_secret      =   self.twitter_keys['consumer_secret'],
            access_token_key     =   self.twitter_keys['access_token_key'],
            access_token_secret  =   self.twitter_keys['access_token_secret']
        )

    def mine_user_tweets(self, user="HL_thall", mine_rewteets=False):

        statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.request_limit)
        data       =   []
        
        for item in statuses:

            mined = {
                'tweet_id': item.id,
                'handle': item.user.name,
                'retweet_count': item.retweet_count,
                'text': item.text,
                'mined_at': datetime.datetime.now(),
                'created_at': item.created_at,
            }
            
            data.append(mined)
            
        return data

# %% [markdown]
# ## Does anyone remember how we "instantiate" a new instance of this class?
#
# **Bonus bonus** How do we call the method to *mine_user_tweets()*?

# %%
# twitter ids:  realDonaldTrump, berniesanders
# Let's test this out here..

miner = twitterminer()
vars(miner)

miner.mine_user_tweets('realDonaldTrump')
# Out:
# [{'created_at': u'Wed Jun 01 13:17:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5848,
#   'text': u'So I raised/gave $5,600,000 for the veterans and the media makes me look bad! They do anything to belittle - totally biased.',
#   'tweet_id': 737996614573260800L},
#  {'created_at': u'Tue May 31 23:18:28 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4106,
#   'text': u'Congratulations to @seanhannity on his tremendous increase in television ratings. Speaking of ratings- I will be on his show tonight @ 10pE.',
#   'tweet_id': 737785345459113985L},
#  {'created_at': u'Tue May 31 23:17:33 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5960,
#   'text': u'I am getting great credit for my press conference today. Crooked Hillary should be admonished for not having a press conference in 179 days.',
#   'tweet_id': 737785114239864832L},
#  {'created_at': u'Tue May 31 23:14:42 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5869,
#   'text': u'Katie Couric, the third rate reporter, who has been largely forgotten, should be ashamed of herself for the fraudulent editing of her doc.',
#   'tweet_id': 737784398515441664L},
#  {'created_at': u'Tue May 31 22:51:56 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2151,
#   'text': u'I will be interviewed on @seanhannity tonight at 10pmE on @FoxNews. Enjoy!',
#   'tweet_id': 737778668785766404L},
#  {'created_at': u'Tue May 31 21:12:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2948,
#   'text': u'Join me in Sacramento, California-tomorrow evening @ 7pm! #Trump2016\nhttps://t.co/W7xy7eXcii https://t.co/km0rRYSDnO',
#   'tweet_id': 737753549564694528L},
#  {'created_at': u'Tue May 31 16:57:17 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5171,
#   'text': u'So many veterans groups are beyond happy with all of the money I raised/gave! It was my great honor - they do an amazing job.',
#   'tweet_id': 737689416811073536L},
#  {'created_at': u'Tue May 31 16:53:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5238,
#   'text': u'Just finished a press conference in Trump Tower wherein I gave information on which VETERANS groups got the $5,600,000 that I raised/gave!',
#   'tweet_id': 737688582849171456L},
#  {'created_at': u'Tue May 31 11:42:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5294,
#   'text': u'I have raised/given a tremendous amount of money to our great VETERANS, and have got nothing but bad publicity for doing so. Watch!',
#   'tweet_id': 737610159459991552L},
#  {'created_at': u'Tue May 31 10:48:49 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3905,
#   'text': u'So many great things happening - new poll numbers looking good! News conference at 11:00 A.M. today, Trump Tower!',
#   'tweet_id': 737596690257969152L},
#  {'created_at': u'Mon May 30 21:55:41 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3873,
#   'text': u'I should have easily won the Trump University case on summary judgement but have a judge, Gonzalo Curiel, who is totally biased against me.',
#   'tweet_id': 737402123453878272L},
#  {'created_at': u'Mon May 30 21:45:09 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3684,
#   'text': u'I have a judge in the Trump University civil case, Gonzalo Curiel (San Diego), who is very unfair. An Obama pick. Totally biased-hates Trump',
#   'tweet_id': 737399475509985280L},
#  {'created_at': u'Mon May 30 20:15:04 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5238,
#   'text': u'I hope everyone had a great Memorial Day!',
#   'tweet_id': 737376803514286081L},
#  {'created_at': u'Mon May 30 20:13:17 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4863,
#   'text': u'I would have had millions of votes more in the primaries (than Crooked Hillary) if I only had one opponent, instead of sixteen. Broke record',
#   'tweet_id': 737376356795875330L},
#  {'created_at': u'Mon May 30 11:26:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 9385,
#   'text': u'Have a great Memorial Day and remember that we will soon MAKE AMERICA GREAT AGAIN!',
#   'tweet_id': 737243856144629760L},
#  {'created_at': u'Mon May 30 11:20:38 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2637,
#   'text': u'"@NBCDFW: Trump rallies veterans at annual Rolling Thunder Gathering https://t.co/b08FcMlgkr https://t.co/RCDeLvHQqD"',
#   'tweet_id': 737242308261842945L},
#  {'created_at': u'Mon May 30 11:20:09 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1528,
#   'text': u'"@FrankyLamouche: how many of donald\'s rolling thunder brigade will sign up and go to war for him in the middle east."',
#   'tweet_id': 737242189055594496L},
#  {'created_at': u'Mon May 30 11:19:29 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4049,
#   'text': u'"@MariaErnandez3b: Trump Supports Rolling Thunder Rally #TRUMP STRONG https://t.co/pfVXQ8NdZu" So true, and remember the M.I.A.\'s!',
#   'tweet_id': 737242018687164416L},
#  {'created_at': u'Mon May 30 11:17:04 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2061,
#   'text': u'"@ScottWRasmussen: Donald Trump and Bikers Share Affection at Rolling Thunder Rally https://t.co/ZZl2sc29dn" A great day in D.C.!',
#   'tweet_id': 737241411465170944L},
#  {'created_at': u'Mon May 30 11:10:12 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3376,
#   'text': u'"@TeaPartyNevada: #Trump2016 "Illegals are taken care of better than our veterans."  https://t.co/KKIgM4rNma https://t.co/1cEZ8wG7Cy"',
#   'tweet_id': 737239685295181824L},
#  {'created_at': u'Mon May 30 11:05:34 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5448,
#   'text': u'The endorsement of me by the 16,500 Border Patrol Agents was the first time that they ever endorsed a presidential candidate. Nice!',
#   'tweet_id': 737238518775320576L},
#  {'created_at': u'Mon May 30 11:00:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4123,
#   'text': u'In getting the endorsement of the 16,500 Border Patrol Agents (thank you), the statement was made that the WALL was very necessary!',
#   'tweet_id': 737237313034563585L},
#  {'created_at': u'Mon May 30 10:41:49 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6391,
#   'text': u"Obama says a WALL at our southern border won't enhance our security (wrong) and yet he now wants to build a much bigger wall (fence) at W.H.",
#   'tweet_id': 737232540436664320L},
#  {'created_at': u'Sun May 29 23:02:01 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5986,
#   'text': u'If dummy Bill Kristol actually does get a spoiler to run as an Independent, say good bye to the Supreme Court!',
#   'tweet_id': 737056428452630528L},
#  {'created_at': u'Sun May 29 22:58:27 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6086,
#   'text': u"The Republican Party has to be smart &amp; strong if it wants to win in November. Can't allow lightweights to set up a spoiler Indie candidate!",
#   'tweet_id': 737055532960223233L},
#  {'created_at': u'Sun May 29 22:53:16 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5054,
#   'text': u"Bill Kristol has been wrong for 2yrs-an embarrassed loser, but if the GOP can't control their own, then they are not a party. Be tough, R's!",
#   'tweet_id': 737054226833149952L},
#  {'created_at': u'Sun May 29 21:43:15 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5716,
#   'text': u'Good news is that my campaign has perhaps more cash than any campaign in the history of politics- b/c I stand 100% behind everything we do.',
#   'tweet_id': 737036608915034112L},
#  {'created_at': u'Sun May 29 16:45:44 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4833,
#   'text': u'Heading to D.C. to see and hear ROLLING THUNDER. Amazing people that LOVE OUR COUNTRY. Great spirit!',
#   'tweet_id': 736961734167146496L},
#  {'created_at': u'Sun May 29 11:04:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 15396,
#   'text': u'Honor Memorial Day by thinking of and respecting all of the great men and women that gave their lives for us and our country! We love them.',
#   'tweet_id': 736875933999697920L},
#  {'created_at': u'Sat May 28 21:34:55 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 11182,
#   'text': u"Does President Obama ever discuss the sneak attack on Pearl Harbor while he's in Japan? Thousands of American lives lost. #MDW",
#   'tweet_id': 736672123012427776L},
#  {'created_at': u'Sat May 28 21:33:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6024,
#   'text': u"Don't believe the biased and phony media quoting people who work for my campaign. The only quote that matters is a quote from me!",
#   'tweet_id': 736671884247478272L},
#  {'created_at': u'Sat May 28 20:28:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5335,
#   'text': u"I am always on the front page of the failing @nytimes, but when I won the GOP nomination, I'm in the back of the paper. Very dishonest!",
#   'tweet_id': 736655485814857728L},
#  {'created_at': u'Sat May 28 20:28:40 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5872,
#   'text': u'The media is on a new phony kick about my management style. I spend much less money &amp; get much better results! What we need as Prez!',
#   'tweet_id': 736655448993107968L},
#  {'created_at': u'Sat May 28 20:28:22 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5343,
#   'text': u"The failing @nytimes wrote a story about my management style &amp; that I don't have many people. I have 73, Hillary has 800- &amp; I'm beating her.",
#   'tweet_id': 736655375911530498L},
#  {'created_at': u'Sat May 28 14:47:16 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8011,
#   'text': u'I (we) broke the all-time record for most votes gotten in a Republican Primary - by a lot - and with many states left to go! Thank you.',
#   'tweet_id': 736569533738156036L},
#  {'created_at': u'Sat May 28 13:47:10 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7068,
#   'text': u'The U.S. has 69 treaties with other countries where we would have to defend them and their borders. How nice, but what do we get? NOT ENOUGH',
#   'tweet_id': 736554410361409536L},
#  {'created_at': u'Sat May 28 06:19:54 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4791,
#   'text': u'Great rally in Fresno, California- great crowd! Thank you! #Trump2016 https://t.co/TVSPvxOmve',
#   'tweet_id': 736441853097218048L},
#  {'created_at': u'Sat May 28 04:13:54 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5117,
#   'text': u"Obama administration fails to screen Syrian refugees' social media accounts:\nhttps://t.co/MMa07nwa44",
#   'tweet_id': 736410143378792448L},
#  {'created_at': u'Sat May 28 02:48:22 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7634,
#   'text': u'.@SanDiegoPD- Fantastic job on handling the thugs who tried to disrupt our very peaceful and well attended rally. Greatly appreciated!',
#   'tweet_id': 736388616214220801L},
#  {'created_at': u'Sat May 28 02:19:19 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4784,
#   'text': u'Thank you @BillyJoel- many friends just told me you gave a very kind shoutout at MSG. Appreciate it- love your music!',
#   'tweet_id': 736381305785581568L},
#  {'created_at': u'Fri May 27 23:20:01 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7305,
#   'text': u'Wow- 25,000 in San Diego, California!\nThank you!! #Trump2016 https://t.co/1NRj3zCuui',
#   'tweet_id': 736336185086222336L},
#  {'created_at': u'Fri May 27 23:19:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1997,
#   'text': u'I am on @oreillyfactor tonight, a big special. @FoxNews  at 8:00 P.M. ENJOY!',
#   'tweet_id': 736336010808688640L},
#  {'created_at': u'Fri May 27 17:35:56 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3046,
#   'text': u"Bill O'Reilly doing a major special on @OreillyFactor tonight- @FoxNews at 8pmE. Watch it, should be good! #Trump2016",
#   'tweet_id': 736249593352966144L},
#  {'created_at': u'Fri May 27 14:10:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5002,
#   'text': u'AN AMERICA FIRST ENERGY PLAN\n#MakeAmericaGreatAgain #Trump2016\nhttps://t.co/kTi6e1zyNI https://t.co/WjI8Rx11no',
#   'tweet_id': 736197797314101248L},
#  {'created_at': u'Fri May 27 02:09:03 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6466,
#   'text': u'Poll data shows that @marcorubio does by far the best in holding onto his Senate seat in Florida. Important to keep the MAJORITY. Run Marco!',
#   'tweet_id': 736016335197458434L},
#  {'created_at': u'Thu May 26 22:57:39 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 9222,
#   'text': u'Today we, together, won the Republican Nomination for President! https://t.co/82l6TjA2lk',
#   'tweet_id': 735968169001684992L},
#  {'created_at': u'Thu May 26 22:22:50 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3100,
#   'text': u'My wife @MELANIATRUMP, and my children will be featured on @FoxNews with @Greta- 7pmE. Enjoy!\n#MeetTheTrumps #Trump2016',
#   'tweet_id': 735959405565378560L},
#  {'created_at': u'Thu May 26 21:30:31 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4573,
#   'text': u'Celebrating 1237! #Trump2016 \nhttps://t.co/hPQJc7eor0',
#   'tweet_id': 735946241322799105L},
#  {'created_at': u'Thu May 26 21:28:22 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4066,
#   'text': u'Thank you! #Trump2016\nhttps://t.co/SPJfMFyPjU',
#   'tweet_id': 735945699834007552L},
#  {'created_at': u'Thu May 26 21:15:16 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 10681,
#   'text': u'I find it offensive that Goofy Elizabeth Warren, sometimes referred to as Pocahontas, pretended to be Native American to get in Harvard.',
#   'tweet_id': 735942401165033477L},
#  {'created_at': u'Thu May 26 18:59:12 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2171,
#   'text': u'Thank you Mr. &amp; Mrs. @TomBarrackJr for the wonderful and magical evening last night. It will not be forgotten. #Trump2016',
#   'tweet_id': 735908158330130432L},
#  {'created_at': u'Thu May 26 16:35:00 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2236,
#   'text': u'.@kimguilfoyle- just watched you on @OutnumberedFNC- thank you!',
#   'tweet_id': 735871869581205504L},
#  {'created_at': u'Thu May 26 13:18:27 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7984,
#   'text': u"The Inspector General's report on Crooked Hillary Clinton is a disaster. Such bad judgement and temperament cannot be allowed in the W.H.",
#   'tweet_id': 735822406514675712L},
#  {'created_at': u'Wed May 25 23:18:54 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5692,
#   'text': u'Thank you Anaheim, California!\n#Trump2016 https://t.co/AEShamhNVS',
#   'tweet_id': 735611127531347969L},
#  {'created_at': u'Wed May 25 18:42:55 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8270,
#   'text': u'Thank you Washington! Honored to say, on behalf of our great movement, we have broken the all time record for votes in GOP primary history.',
#   'tweet_id': 735541674793783297L},
#  {'created_at': u'Wed May 25 13:39:38 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 13103,
#   'text': u'The protesters in New Mexico were thugs who were flying the Mexican flag. The rally inside was big and beautiful, but outside, criminals!',
#   'tweet_id': 735465352436408320L},
#  {'created_at': u'Wed May 25 13:14:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7982,
#   'text': u"Crooked Hillary Clinton just can't close the deal with Bernie. I had to knock out 16 very good and smart candidates. Hillary doesn't have it",
#   'tweet_id': 735459144287719425L},
#  {'created_at': u'Wed May 25 12:31:56 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4936,
#   'text': u'Goofy Senator Elizabeth Warren @elizabethforma has done less in the U.S. Senate than practically any other senator. All talk, no action!',
#   'tweet_id': 735448311914602496L},
#  {'created_at': u'Wed May 25 12:17:40 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4118,
#   'text': u'@elizabethforma  Goofy Elizabeth Warren, sometimes known as Pocahontas, bought foreclosed housing and made a quick killing. Total hypocrite!',
#   'tweet_id': 735444721716199424L},
#  {'created_at': u'Wed May 25 05:47:45 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2853,
#   'text': u'"@gordonsr1052:  Washington, BIG Thank You for supporting Trump! We are all going to help Trump Make America Great Again! Trump2016!"',
#   'tweet_id': 735346597303816192L},
#  {'created_at': u'Wed May 25 05:45:19 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1989,
#   'text': u'"@buiIdthewall: @realDonaldTrump high energy!"',
#   'tweet_id': 735345985455554560L},
#  {'created_at': u'Wed May 25 05:45:11 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1834,
#   'text': u'"@PiperSul: Great speech tonight Mr.Trump! Good Luck in California! Thank you.',
#   'tweet_id': 735345952756801536L},
#  {'created_at': u'Wed May 25 05:42:59 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1677,
#   'text': u'"@DeepakS76435750: @realDonaldTrump congratulations from India"',
#   'tweet_id': 735345398437556225L},
#  {'created_at': u'Wed May 25 05:42:49 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2710,
#   'text': u'"@oasisupernova: @realDonaldTrump UP TO 8.4 MILLION FOLLOWERS. CAN\'T STOP THE #TrumpTrain \U0001f682 #MakeAmericaGreatAgain"',
#   'tweet_id': 735345354992975873L},
#  {'created_at': u'Wed May 25 05:41:38 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1163,
#   'text': u'"@jknatter: @realDonaldTrump #TrumpTrain"',
#   'tweet_id': 735345057587417089L},
#  {'created_at': u'Wed May 25 05:41:30 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1428,
#   'text': u'"@tcloer11: @realDonaldTrump Great job! Make America Great Again!"',
#   'tweet_id': 735345023563247617L},
#  {'created_at': u'Wed May 25 05:37:29 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2172,
#   'text': u'@elizabethforma Goofy Elizabeth Warren, sometimes referred to as Pocahontas because she faked the fact she is native American, is a lowlife!',
#   'tweet_id': 735344013499326465L},
#  {'created_at': u'Wed May 25 05:12:44 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3225,
#   'text': u'Great rally in New Mexico, amazing crowd! Now in L.A. Big rally in Anaheim.',
#   'tweet_id': 735337786757238785L},
#  {'created_at': u'Wed May 25 03:26:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4854,
#   'text': u'Thank you Washington! #Trump2016\n#MakeAmericaGreatAgain https://t.co/v9glTwj6gy',
#   'tweet_id': 735311006826700800L},
#  {'created_at': u'Wed May 25 00:33:27 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4793,
#   'text': u"Great honor to receive today's endorsement of @RickSantorum. Really nice! #Trump2016",
#   'tweet_id': 735267499269226496L},
#  {'created_at': u'Wed May 25 00:32:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5130,
#   'text': u"After raising, w/ no obligation, almost $6M for Vets, I couldn't believe protesters formed @ Trump Tower. JUST OUT- SENT BY CROOKED HILLARY!",
#   'tweet_id': 735267332927279107L},
#  {'created_at': u'Tue May 24 21:00:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5571,
#   'text': u"Thank you @DailyMail- for setting the failing @NYTimes story straight. This is what the NYT's should have written! \nhttps://t.co/Feb6dhctQo",
#   'tweet_id': 735213812484345857L},
#  {'created_at': u'Tue May 24 15:09:24 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3863,
#   'text': u'A suggestion for the dishonest media- https://t.co/zKyRwEaLmz',
#   'tweet_id': 735125552064024577L},
#  {'created_at': u'Tue May 24 15:03:39 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3563,
#   'text': u'A wonderfully written article concerning Israel by @JasonDovEsq https://t.co/LZ9qWRYzdj',
#   'tweet_id': 735124106476195841L},
#  {'created_at': u'Tue May 24 14:35:32 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6610,
#   'text': u'A great new book has been written about Crooked Hillary. Read it &amp; you will never be able to vote for her. @Ed_Klein https://t.co/ujDwSSFhbx',
#   'tweet_id': 735117032060899328L},
#  {'created_at': u'Tue May 24 11:42:35 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7079,
#   'text': u"Crooked Hillary Clinton overregulates, overtaxes and doesn't care about jobs. Most importantly, she suffers from plain old bad judgement!",
#   'tweet_id': 735073508124983298L},
#  {'created_at': u'Tue May 24 10:41:44 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5395,
#   'text': u'I just released my financial disclosure forms, the largest numbers in the history of the F.E.C. Even the dishonest media thinks great!',
#   'tweet_id': 735058192862969856L},
#  {'created_at': u'Tue May 24 02:50:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8109,
#   'text': u'Amazingly, with all of the money I have raised for the vets, I have got nothing but bad publicity from the dishonest and disgusting media.',
#   'tweet_id': 734939680278519809L},
#  {'created_at': u'Tue May 24 02:46:08 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5171,
#   'text': u'Much of the money I have raised for our veterans has already been distributed, with the rest to go shortly to various other veteran groups.',
#   'tweet_id': 734938503541325825L},
#  {'created_at': u'Tue May 24 02:38:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7208,
#   'text': u'While under no obligation to do so, I have raised between 5 &amp; 6 million dollars, including 1million dollars from me, for our VETERANS. Nice!',
#   'tweet_id': 734936659851128832L},
#  {'created_at': u'Tue May 24 00:25:41 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3120,
#   'text': u'Join me in California or Montana!\n5/25/16: Anaheim, California\nhttps://t.co/mmPck1HYrC\n5/26/16: Billings, Montana\nhttps://t.co/atvrCgjFDe',
#   'tweet_id': 734903156589645824L},
#  {'created_at': u'Mon May 23 23:42:39 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2111,
#   'text': u'I will be interviewed on @oreillyfactor at 8:00 P.M. Enjoy!',
#   'tweet_id': 734892328637325312L},
#  {'created_at': u'Mon May 23 17:15:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7623,
#   'text': u"Obama\u2019s VA Secretary just said we shouldn't measure\nwait times. Hillary says VA problems are not \u2018widespread.\u2019 I will take care of\nour vets!",
#   'tweet_id': 734794856564936705L},
#  {'created_at': u'Mon May 23 15:32:11 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4460,
#   'text': u'Is Hillary really protecting women? https://t.co/8ZtEIWNqz4',
#   'tweet_id': 734768900282454016L},
#  {'created_at': u'Mon May 23 13:46:57 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8445,
#   'text': u'In trade, military and EVERYTHING else, it will be AMERICA FIRST! This will quickly lead to our ultimate goal: MAKE AMERICA GREAT AGAIN!',
#   'tweet_id': 734742416494845952L},
#  {'created_at': u'Sun May 22 22:54:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 12256,
#   'text': u'Thank you America! #Trump2016 https://t.co/xfINxdRNiQ',
#   'tweet_id': 734517899960934400L},
#  {'created_at': u'Sun May 22 20:44:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8974,
#   'text': u'The American people are sick and tired of not being able to lead normal lives and to constantly be on the lookout for terror and terrorists!',
#   'tweet_id': 734485185148944384L},
#  {'created_at': u'Sun May 22 20:32:33 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6274,
#   'text': u'Bernie Sanders is continuing his quest because he believes that Crooked Hillary Clinton will be forced out of the race - e-mail scandal!',
#   'tweet_id': 734482099793711104L},
#  {'created_at': u'Sun May 22 19:46:57 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3707,
#   'text': u'Join me on Wednesday, May 25th at the Anaheim Convention Center!\n#Trump2016 #MAGA \nTickets: https://t.co/mmPck1HYrC https://t.co/xGkVbxTamz',
#   'tweet_id': 734470625767620609L},
#  {'created_at': u'Sun May 22 19:38:18 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 9778,
#   'text': u'Crooked Hillary wants a radical 500% increase in Syrian refugees. We can\u2019t allow this. Time to get smart and protect America!',
#   'tweet_id': 734468447829004288L},
#  {'created_at': u'Sun May 22 19:37:05 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 12965,
#   'text': u'How can Crooked Hillary say she cares about women when she is silent on radical Islam, which horribly oppresses women?',
#   'tweet_id': 734468142303305728L},
#  {'created_at': u'Sun May 22 15:28:44 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4436,
#   'text': u'RT @gatewaypundit: BREAKING POLL: Trump Gains 11 Points on Clinton Since March=&gt; Now Leads Crooked Hillary 46-44 https://t.co/y3BGy15Erb vi\u2026',
#   'tweet_id': 734405641893249024L},
#  {'created_at': u'Sun May 22 14:47:45 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5153,
#   'text': u'Why do the networks continue to put dopey @BillKristol on panels when he has called every single shot about me wrong for 2 yrs?',
#   'tweet_id': 734395329588670465L},
#  {'created_at': u'Sun May 22 12:47:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 11031,
#   'text': u'Hillary Clinton is not qualified to be president because her judgement has been proven to be so bad! Would be four more years of stupidity!',
#   'tweet_id': 734365143635759104L},
#  {'created_at': u'Sun May 22 03:55:39 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6168,
#   'text': u'Crooked Hillary said that I  want guns brought into the school classroom. Wrong!',
#   'tweet_id': 734231223002894337L},
#  {'created_at': u'Sun May 22 03:44:05 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3060,
#   'text': u'"@dubilujane: I trust @realDonaldTrump more anyone ever to protect America.He WILL do the right thing for the U.S.A, without a  doubt.',
#   'tweet_id': 734228313695236100L},
#  {'created_at': u'Sat May 21 20:13:08 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 10418,
#   'text': u'Thank you to all of the men and women who have served our country. You are our true heroes! #ArmedForcesDay https://t.co/A3Wus0cRIO',
#   'tweet_id': 734114828529307648L},
#  {'created_at': u'Sat May 21 17:02:41 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7499,
#   'text': u'Crooked Hillary Clintons foreign interventions unleashed ISIS in Syria, Iraq and Libya. She is reckless and dangerous!',
#   'tweet_id': 734066896794963968L},
#  {'created_at': u'Sat May 21 17:00:42 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 9397,
#   'text': u'MAKE AMERICA GREAT AGAIN! https://t.co/MAZK5bdZuD',
#   'tweet_id': 734066397425307648L},
#  {'created_at': u'Sat May 21 16:08:26 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4704,
#   'text': u'.@CNN is so negative, getting even worse as I get closer. Just had two anti-Trump losers with zero rebuttal from my team. Turning off!',
#   'tweet_id': 734053246734499840L},
#  {'created_at': u'Sat May 21 13:34:02 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5155,
#   'text': u'"@RBacliff: Hillary wants to rip the guns out of America\'s hands. No guns = no protection. Get on #TrumpTrain &amp; join @NRA to stop her."',
#   'tweet_id': 734014390731673600L},
#  {'created_at': u'Sat May 21 12:49:59 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 16291,
#   'text': u'Crooked Hillary wants to get rid of all guns and yet she is surrounded by bodyguards who are fully armed. No more guns to protect Hillary!',
#   'tweet_id': 734003305819570176L},
#  {'created_at': u'Sat May 21 10:56:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8809,
#   'text': u'While our wonderful president was out playing golf all day, the TSA is falling apart, just like our government! Airports a total disaster!',
#   'tweet_id': 733974704445358080L},
#  {'created_at': u'Sat May 21 01:56:44 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7211,
#   'text': u'Crooked Hillary is spending tremendous amounts of Wall Street money on false ads against me. She is a very dishonest person!',
#   'tweet_id': 733838909805887488L},
#  {'created_at': u'Sat May 21 01:51:57 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8538,
#   'text': u'Crooked Hillary Clinton wants to essentially abolish the 2nd Amendment. No gun owner can ever vote for Clinton!',
#   'tweet_id': 733837704312410112L},
#  {'created_at': u'Sat May 21 00:44:43 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1964,
#   'text': u'Thank you @TheTodaysGolfer for the wonderful statement that "the new par 3 9th hole @Trump Turnberry could be the most dramatic in Britain."',
#   'tweet_id': 733820785157132288L},
#  {'created_at': u'Fri May 20 23:36:17 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1164,
#   'text': u'@montgomeriefdn  Colin, great to have you at Trump Turnberry. So proud of you and your GREAT playing! You made winning MAJORS look easy!',
#   'tweet_id': 733803565060345856L},
#  {'created_at': u'Fri May 20 23:27:38 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2004,
#   'text': u'"@montgomeriefdn: @TrumpTurnberry Best Links Course in Britain. Ailsa Course opens June \'16 Can\'t wait to play it https://t.co/HnQbj3ipuS"',
#   'tweet_id': 733801387952340992L},
#  {'created_at': u'Fri May 20 22:50:18 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4955,
#   'text': u'Thank you for your wonderful endorsement today @TGowdySC. It means a great deal to me. We will not disappoint! #Trump2016',
#   'tweet_id': 733791992564617216L},
#  {'created_at': u'Fri May 20 21:55:40 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4836,
#   'text': u'Great day in Kentucky with Wayne LaPierre, Chris Cox &amp; the @NRA! \n#MakeAmericaGreatAgain #Trump2016 https://t.co/aJ7s0aqqj0',
#   'tweet_id': 733778244076507136L},
#  {'created_at': u'Fri May 20 20:06:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7088,
#   'text': u'Thank you! An honor to be the first candidate ever endorsed by the @NRA- prior to @GOPconvention! #Trump2016 #2A  https://t.co/ygLUAl7gzx',
#   'tweet_id': 733750845280522242L},
#  {'created_at': u'Fri May 20 16:11:21 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3829,
#   'text': u'Failing @NYTimes will always take a good story about me and make it bad. Every article is unfair and biased. Very sad!',
#   'tweet_id': 733691591198703616L},
#  {'created_at': u'Fri May 20 16:09:16 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4945,
#   'text': u'Thanks @piersmorgan! \n"Trump is the most unpredictable, extraordinary, entertaining&amp;massively popular candidate this country has ever seen."',
#   'tweet_id': 733691067829215232L},
#  {'created_at': u'Fri May 20 15:36:44 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6717,
#   'text': u'Crooked Hillary Clinton- discussing the #SecondAmendment at a private event. #2A cc: @NRA https://t.co/vV31Pbpkmn',
#   'tweet_id': 733682878278696960L},
#  {'created_at': u'Fri May 20 15:15:08 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2788,
#   'text': u'I am on my way! See you all soon! https://t.co/Arw19Antpj',
#   'tweet_id': 733677446235623425L},
#  {'created_at': u'Fri May 20 14:30:06 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2168,
#   'text': u'"A Call for Unity" by Jason Greenblatt @JasonDovEsq https://t.co/dQi3Cydckp',
#   'tweet_id': 733666112563519489L},
#  {'created_at': u'Fri May 20 10:26:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6563,
#   'text': u"Crooked Hillary can't even close the deal with Bernie - and the Dems have it rigged in favor of Hillary. Four more years of this? No way!",
#   'tweet_id': 733604767612710912L},
#  {'created_at': u'Fri May 20 10:08:49 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6354,
#   'text': u"Crooked Hillary Clinton looks presidential? I don't think so! Four more years of Obama and our country will never come back. ISIS LAUGHS!",
#   'tweet_id': 733600358501625857L},
#  {'created_at': u'Fri May 20 09:58:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6131,
#   'text': u'Look where the world is today, a total mess, and ISIS is still running around wild. I can fix it fast, Hillary has no chance!',
#   'tweet_id': 733597831261499392L},
#  {'created_at': u'Fri May 20 09:47:09 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4900,
#   'text': u'Crooked Hillary has zero imagination and even less stamina. ISIS, China, Russia and all would love for her to be president. 4 more years!',
#   'tweet_id': 733594906447372292L},
#  {'created_at': u'Fri May 20 09:40:37 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5618,
#   'text': u'I said that Crooked Hillary Clinton is "not qualified" to be president because she has "very bad judgement" - Bernie said the same thing!',
#   'tweet_id': 733593259423862785L},
#  {'created_at': u'Thu May 19 19:36:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5108,
#   'text': u'Thank you @LtStevenLRogers. We will respond to terrorism with strength in 2017!\nhttps://t.co/Mk4YuuRf4s',
#   'tweet_id': 733380950059581440L},
#  {'created_at': u'Thu May 19 17:29:36 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5289,
#   'text': u'How quality a woman is Rowanne Brewer Lane to have exposed the @nytimes as a disgusting fraud?  Thank you Rowanne.',
#   'tweet_id': 733348895615528960L},
#  {'created_at': u'Thu May 19 10:27:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 13180,
#   'text': u'Looks like yet another terrorist attack. Airplane departed from Paris. When will we get tough, smart and vigilant? Great hate and sickness!',
#   'tweet_id': 733242745385537536L},
#  {'created_at': u'Thu May 19 02:52:29 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4731,
#   'text': u'My list of potential U.S. Supreme Court Justices was very well recieved. During the next number of weeks I may be adding to the list!',
#   'tweet_id': 733128160603168768L},
#  {'created_at': u'Thu May 19 01:54:08 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4754,
#   'text': u'Some low-life journalist claims that I "made a pass" at her 29 years ago. Never happened! Like the @nytimes story which has become a joke!',
#   'tweet_id': 733113480207798272L},
#  {'created_at': u'Wed May 18 23:14:39 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4984,
#   'text': u'#MakeAmericaGreatAgain #Trump2016\nhttps://t.co/kXhc2j94YF https://t.co/YZAdAndKXv',
#   'tweet_id': 733073344661061632L},
#  {'created_at': u'Wed May 18 17:47:19 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4984,
#   'text': u'Thank you Louisiana! #Trump2016 https://t.co/u8hhrRRFMp',
#   'tweet_id': 732990965426888705L},
#  {'created_at': u'Wed May 18 17:38:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4359,
#   'text': u'Thank you Arizona! See you soon!\n#MakeAmericaGreatAgain https://t.co/IC3pe5lRAS',
#   'tweet_id': 732988705531650048L},
#  {'created_at': u'Wed May 18 16:39:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3609,
#   'text': u"Why did Clinton supporter @AlisonForKY declare Crooked Hillary winner in KY when AP hasn't even called the race?",
#   'tweet_id': 732973805354819586L},
#  {'created_at': u'Wed May 18 11:20:19 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 7538,
#   'text': u'Bernie Sanders is being treated very badly by the Democrats - the system is rigged against him. Many of his disenfranchised fans are for me!',
#   'tweet_id': 732893573365010432L},
#  {'created_at': u'Wed May 18 04:22:01 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4883,
#   'text': u'Paul Begala, the dopey @CNN flunky and head of the Pro-Hillary Clinton Super PAC, has knowingly committed fraud in his first ad against me.',
#   'tweet_id': 732788306237345794L},
#  {'created_at': u'Wed May 18 04:03:08 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3135,
#   'text': u'"@ShoneeP: @realDonaldTrump Trump for President! Bernie is a joke, knows nothing - and Hillary is yesterday\'s and today\'s nightmare"',
#   'tweet_id': 732783552513880064L},
#  {'created_at': u'Wed May 18 03:46:26 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3803,
#   'text': u'"@MagicMetalNinja:  The Trump movement will not be stopped. We support Trump because he is a true American looking out for #AmericaFIRST."',
#   'tweet_id': 732779353566760960L},
#  {'created_at': u'Wed May 18 03:24:48 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 6557,
#   'text': u'Congratulations to THE MOVEMENT, we have just won THE GREAT STATE OF OREGON. The vote percentage is even higher than anticipated! Thank you.',
#   'tweet_id': 732773906889736192L},
#  {'created_at': u'Wed May 18 03:15:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5005,
#   'text': u'Thank you Oregon! #Trump2016 \n#MakeAmericaGreatAgain https://t.co/hK1yqlp9ca',
#   'tweet_id': 732771469281927169L},
#  {'created_at': u'Wed May 18 02:41:22 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3706,
#   'text': u'"@LouDobbs: Hillary Just Handed @realDonaldTrump a Huge Gift: Promising to Put Bubba in Charge of the Economy! #MakeAmericaGreatAgain!',
#   'tweet_id': 732762977825349632L},
#  {'created_at': u'Wed May 18 02:40:34 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3605,
#   'text': u'"@sandrajeanne48: No way I believe Trump at 70% disapproval with women. Went to 3 rallies. At least 1/2 women. MSM LIES @TheFive"',
#   'tweet_id': 732762774745559041L},
#  {'created_at': u'Wed May 18 02:38:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3156,
#   'text': u'Michael Barbaro, the author of the now discredited @nytimes hit piece on me with women, has in past tweeted badly about me. He should resign',
#   'tweet_id': 732762160842039296L},
#  {'created_at': u'Wed May 18 02:14:51 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2228,
#   'text': u'"@michael_favreau: @JIS3 @realDonaldTrump He will destroy Hillary but why give CNN record breaking ratings CNN can go to hell. Trump 2016"',
#   'tweet_id': 732756302447968257L},
#  {'created_at': u'Wed May 18 01:53:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
# ...
#  {'created_at': u'Wed May 18 00:42:29 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1209,
#   'text': u'"@Janik1968: @realDonaldTrump @SpeakerRyan Watched the Megan Kelly special and I must say..it was very well done on both their parts"',
#   'tweet_id': 732733059955601408L},
#  {'created_at': u'Wed May 18 00:41:23 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1047,
#   'text': u'"@KaceyIlliot1669: @realDonaldTrump We actually really do love you!" Great!',
#   'tweet_id': 732732783605469184L},
#  {'created_at': u'Wed May 18 00:41:06 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1162,
#   'text': u'"@johnkirtley:  @megynkelly @realDonaldTrump #MakeAmericaGreatAgain Thank you for this discourse. Wounds have been healed. Great job!"',
#   'tweet_id': 732732712268746753L},
#  {'created_at': u'Wed May 18 00:40:41 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1034,
#   'text': u'"@jlund04: @megynkelly @realDonaldTrump it was refreshing to see you both in a different light. Well done."',
#   'tweet_id': 732732606765240321L},
#  {'created_at': u'Wed May 18 00:37:13 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1698,
#   'text': u'"@FrankDallasAgg: @megynkelly @realDonaldTrump Trump is a great man and is FIGHTING for We The People!"',
#   'tweet_id': 732731735897702400L},
#  {'created_at': u'Wed May 18 00:35:40 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1182,
#   'text': u'"@LADYJOANNE: @megynkelly @realDonaldTrump we need Trump more then ever Megyn. Thanks.',
#   'tweet_id': 732731343503790080L},
#  {'created_at': u'Wed May 18 00:34:55 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1065,
#   'text': u'"@LADYJOANNE: @megynkelly @realDonaldTrump we need Trump more then ever Megan Please don\'t lose it for America for us!"',
#   'tweet_id': 732731153556312064L},
#  {'created_at': u'Wed May 18 00:33:40 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1651,
#   'text': u'"@curtandkaren: Kudos to @megynkelly and @realDonaldTrump for rising above the drama and coming together. Very respectful and classy \U0001f44d"',
#   'tweet_id': 732730840162144256L},
#  {'created_at': u'Wed May 18 00:32:39 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1093,
#   'text': u'"@gerriweth: @megynkelly @realDonaldTrump Made me feel good to hear you both so gracious. Great job"',
#   'tweet_id': 732730584695463936L},
#  {'created_at': u'Wed May 18 00:32:10 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1513,
#   'text': u'"@SandraR67758219: @realDonaldTrump You are a fighter and we LOVE that about you! Don\'t listen to these people who want you to change!"',
#   'tweet_id': 732730463735943169L},
#  {'created_at': u'Wed May 18 00:29:19 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1032,
#   'text': u'"@longbyfive: @realDonaldTrump great interview with @megynkelly !" Thanks.',
#   'tweet_id': 732729747336269824L},
#  {'created_at': u'Wed May 18 00:28:49 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1697,
#   'text': u'"@HFFoundation4: @realDonaldTrump One thing we know for sure @BernieSanders supporters will turn to #Trump - absolutely not @HillaryClinton"',
#   'tweet_id': 732729619061821440L},
#  {'created_at': u'Wed May 18 00:27:41 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1489,
#   'text': u'"@wesleyfelixpsi: @realDonaldTrump speaks from the heart 4 all of America.His intention is for a positive future 4 all. @FoxNews @megynkelly',
#   'tweet_id': 732729332917997568L},
#  {'created_at': u'Wed May 18 00:26:43 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1562,
#   'text': u'"@manakoa:DonaldTrump, you are fearless! This interview shows you are the Leader we need. @megynkelly is a tough interview! Respect to both"',
#   'tweet_id': 732729090696957954L},
#  {'created_at': u'Wed May 18 00:15:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1039,
#   'text': u'"@ragdollive: @megynkelly @realDonaldTrump what\'s with the soft wimpy questions?!? It\'s not a therapy session ..!!" Not really soft at all!',
#   'tweet_id': 732726338147258370L},
#  {'created_at': u'Wed May 18 00:14:51 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1035,
#   'text': u'"@xGodfatherxzx: @realDonaldTrump amazing on Megan Kelly" Thanks.',
#   'tweet_id': 732726105837277184L},
#  {'created_at': u'Wed May 18 00:06:45 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1096,
#   'text': u'"@TrumpTrainRider: .@realDonaldTrump Watching you on Fox with @megynkelly now. Can\'t wait to hear what you two talked about."',
#   'tweet_id': 732724066122104832L},
#  {'created_at': u'Tue May 17 23:49:47 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 1683,
#   'text': u'I will be live tweeting @megynkelly Show in 10 minutes. Should be interesting. Will be on Fox Network! ENJOY!',
#   'tweet_id': 732719796077383680L},
#  {'created_at': u'Tue May 17 23:42:33 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2655,
#   'text': u'Wall Street paid for ad is a fraud, just like Crooked Hillary! Their main line had nothing to do with women, and they knew it. Apologize?',
#   'tweet_id': 732717975090909185L},
#  {'created_at': u'Tue May 17 23:37:06 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3803,
#   'text': u"Do you think Crooked Hillary will finally close the deal? If she can't win Kentucky, she should drop out of race. System rigged!",
#   'tweet_id': 732716604027502592L},
#  {'created_at': u'Tue May 17 21:19:17 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5509,
#   'text': u'I will be live tweeting my interview with @megynkelly on the Fox Network tonight at 8! Enjoy! https://t.co/nlJssZeIWm',
#   'tweet_id': 732681922644725760L},
#  {'created_at': u'Tue May 17 15:25:41 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3366,
#   'text': u'I look forward to watching @megynkelly tonight, 8 PM ET. It will be interesting to see how she treats me\u2014I think she will be very fair.',
#   'tweet_id': 732592935980695558L},
#  {'created_at': u'Tue May 17 14:21:55 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8772,
#   'text': u'How can Crooked Hillary put her husband in charge of the economy when he was responsible for NAFTA, the worst economic deal in U.S. history?',
#   'tweet_id': 732576889538260992L},
#  {'created_at': u'Tue May 17 14:17:07 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5524,
#   'text': u'Crooked Hillary said her husband is going to be in charge of the economy.If so, he should run,not her.Will he bring the "energizer" to D.C.?',
#   'tweet_id': 732575682367258624L},
#  {'created_at': u'Tue May 17 13:58:08 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 2921,
#   'text': u"#VoteTrump at clerk's offices &amp; 185 ballot drop boxes in #ORPrimary!\nCloses at 8pm! https://t.co/ESGg1Qu68S\nhttps://t.co/TqcNAWjP5l",
#   'tweet_id': 732570904094347265L},
#  {'created_at': u'Tue May 17 12:31:53 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3876,
#   'text': u"Crooked Hillary can't close the deal with Bernie Sanders. Will be another bad day for her!",
#   'tweet_id': 732549197539446784L},
#  {'created_at': u'Tue May 17 11:58:10 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 15178,
#   'text': u'Amazing that Crooked Hillary can do a hit ad on me concerning women when her husband was the WORST abuser of woman in U.S. political history',
#   'tweet_id': 732540713678819328L},
#  {'created_at': u'Tue May 17 11:52:00 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4196,
#   'text': u'Oregon is voting today. Keep the big numbers going - VOTE TRUMP! MAKE AMERICA GREAT AGAIN!',
#   'tweet_id': 732539159659859968L},
#  {'created_at': u'Tue May 17 11:46:22 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3775,
#   'text': u"Crooked Hillary Clinton put out an ad where I am misquoted on women. Can't believe she would misrepresent the facts! My hit was on China",
#   'tweet_id': 732537744195522560L},
#  {'created_at': u'Tue May 17 11:37:03 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5084,
#   'text': u'The pathetic new hit ad against me misrepresents the final line. "You can tell them to go BLANK themselves" - was about China, NOT WOMEN!',
#   'tweet_id': 732535400498143232L},
#  {'created_at': u'Tue May 17 11:29:09 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 8825,
#   'text': u'Wow, 30,000 e-mails were deleted by Crooked Hillary Clinton. She said they had to do with a wedding reception. Liar! How can she run?',
#   'tweet_id': 732533409285865473L},
#  {'created_at': u'Tue May 17 04:40:38 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3752,
#   'text': u'"@AprilLaJune: OREGON votes today! Go vote for @realDonaldTrump and kick it BIG TIME! https://t.co/SLYwyM8w1D"',
#   'tweet_id': 732430605548437504L},
#  {'created_at': u'Tue May 17 04:02:45 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3172,
#   'text': u'What Barbara Res does not say is that she would call my company endlessly, and for years, trying to come back. I said no.',
#   'tweet_id': 732421072037892101L},
#  {'created_at': u'Tue May 17 03:46:35 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4057,
#   'text': u'I gave a woman named Barbara Res a top N.Y. construction job, when that was unheard of, and now she is nasty. So much for a nice thank you!',
#   'tweet_id': 732417001965137920L},
#  {'created_at': u'Tue May 17 01:08:17 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 9920,
#   'text': u'"In politics, and in life, ignorance is not a virtue." This is a primary reason that President Obama is the worst president in U.S. history!',
#   'tweet_id': 732377163505225728L},
#  {'created_at': u'Mon May 16 22:15:52 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4661,
#   'text': u'The writer of the now proven false story in the @nytimes, Michael Barbaro, who was interviewed on CBS this morning, was unable to respond.',
#   'tweet_id': 732333772587302912L},
#  {'created_at': u'Mon May 16 22:14:19 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5114,
#   'text': u'Over 50 women were interviewed by the @nytimes yet they only wrote about 6. That\u2019s because there were so many positive statements.',
#   'tweet_id': 732333383024582661L},
#  {'created_at': u'Mon May 16 22:13:20 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3958,
#   'text': u'No wonder the @nytimes is failing\u2014who can believe what they write after the false, malicious &amp; libelous story they did on me.',
#   'tweet_id': 732333137326444544L},
#  {'created_at': u'Mon May 16 22:12:53 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3588,
#   'text': u'The failing @nytimes is greatly embarrassed by the totally dishonest story they did on my relationship with women.',
#   'tweet_id': 732333025325928448L},
#  {'created_at': u'Mon May 16 21:50:40 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4071,
#   'text': u'Rowanne Brewer, the most prominently depicted woman in the failing @nytimes story yesterday joined @foxandfriends. \nhttps://t.co/qkK3LJPoQQ',
#   'tweet_id': 732327433957953537L},
#  {'created_at': u'Mon May 16 18:19:42 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 3155,
#   'text': u'Thank you, Anthony @Scaramucci @WSJ "The Entrepreneur\'s Case for Trump"  https://t.co/xm45Ia1GTu',
#   'tweet_id': 732274340188852224L},
#  {'created_at': u'Mon May 16 15:25:02 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 5833,
#   'text': u'With the coming forward today of the woman central to the failing @nytimes hit piece on me, we have exposed the article as a fraud!',
#   'tweet_id': 732230384071680001L},
#  {'created_at': u'Mon May 16 13:24:21 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4232,
#   'text': u'A political commentator for @cnn, which I no longer watch, said "Trump showed some weakness in the Repub Primaries." I set all-time record!',
#   'tweet_id': 732200012457906176L},
#  {'created_at': u'Mon May 16 13:12:38 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4758,
#   'text': u'Wow, Rowanne Brewer, the most prominently depicted woman in the failing @nytimes story yesterday, was on @foxandfriends saying Times lied',
#   'tweet_id': 732197065820913668L},
#  {'created_at': u'Mon May 16 13:09:26 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4516,
#   'text': u'The @nytimes is so dishonest. Their hit piece cover story on me yesterday was just blown up by Rowanne Brewer, who said it was a lie!',
#   'tweet_id': 732196260636151808L},
#  {'created_at': u'Mon May 16 11:00:58 +0000 2016',
#   'handle': u'Donald J. Trump',
#   'mined_at': datetime.datetime(2016, 6, 1, 11, 57, 36, 405000),
#   'retweet_count': 4317,
#   'text': u'That was an amazing interview on @foxandfriends - I hope the rest of the media picks it up to show how totally dishonest the @nytimes is!',
#   'tweet_id': 732163930236260352L}]

# %% [markdown]
# ##  Now we create some training data
#
# We will have to munge a little bit in order to get our "mined" data from the Twitter API.
#
#  - Mine Trump Tweets
#  - Create DataFrame
#  - Mine Sanders Tweets
#  - Append to DataFrame

# %%
## we only need to "instantiate" once.  Then we can call mine_user_tweets as much as we want.
miner = twitterminer(request_limit=500)
trump_tweets = miner.mine_user_tweets("realDonaldTrump")

# %%
trump_df = pd.DataFrame(trump_tweets)
trump_df.head(10)
# Out:
# (200, 6)
#                        created_at           handle                mined_at  \
# 0  Wed Jun 01 13:17:58 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 1  Tue May 31 23:18:28 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 2  Tue May 31 23:17:33 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 3  Tue May 31 23:14:42 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 4  Tue May 31 22:51:56 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 5  Tue May 31 21:12:07 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 6  Tue May 31 16:57:17 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 7  Tue May 31 16:53:58 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 8  Tue May 31 11:42:20 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
# 9  Tue May 31 10:48:49 +0000 2016  Donald J. Trump 2016-06-01 11:57:46.492
#
#    retweet_count                                               text  \
# 0           5849  So I raised/gave $5,600,000 for the veterans a...
# 1           4106  Congratulations to @seanhannity on his tremend...
# 2           5960  I am getting great credit for my press confere...
# 3           5869  Katie Couric, the third rate reporter, who has...
# 4           2151  I will be interviewed on @seanhannity tonight ...
# 5           2948  Join me in Sacramento, California-tomorrow eve...
# 6           5171  So many veterans groups are beyond happy with ...
# 7           5238  Just finished a press conference in Trump Towe...
# 8           5294  I have raised/given a tremendous amount of mon...
# 9           3905  So many great things happening - new poll numb...
#
#              tweet_id
# 0  737996614573260800
# 1  737785345459113985
# 2  737785114239864832
# 3  737784398515441664
# 4  737778668785766404
# 5  737753549564694528
# 6  737689416811073536
# 7  737688582849171456
# 8  737610159459991552
# 9  737596690257969152

# %% [markdown]
# ## Any interesting ngrams going on with Trump?

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,2))

# Pulls all of trumps tweet text's into one giant string
summaries = "".join(trump_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(10)
# Out:
# [(u'https co', 49),
#  (u'crooked hillary', 26),
#  (u'thank you', 22),
#  (u'of the', 18),
#  (u'hillary clinton', 13),
#  (u'will be', 13),
#  (u'in the', 12),
#  (u'trump2016 https', 11),
#  (u'megynkelly realdonaldtrump', 10),
#  (u'to be', 9)]

# %% [markdown]
# ## (10 mins) Try this exercize with Bernie Sanders..

# %%
sanders_tweets = miner.mine_user_tweets("berniesanders")

# %%
sanders_df = pd.DataFrame(sanders_tweets)
sanders_df.head(10)
# Out:
#                        created_at          handle                mined_at  \
# 0  Wed Jun 01 18:04:31 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 1  Wed Jun 01 17:07:42 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 2  Wed Jun 01 16:41:55 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 3  Wed Jun 01 16:24:02 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 4  Wed Jun 01 14:58:07 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 5  Wed Jun 01 13:21:07 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 6  Wed Jun 01 02:55:20 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 7  Wed Jun 01 01:53:44 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 8  Wed Jun 01 01:52:34 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
# 9  Wed Jun 01 00:46:01 +0000 2016  Bernie Sanders 2016-06-01 11:51:11.832
#
#    retweet_count                                               text  \
# 0            480  We need to implement a nationwide ban on frack...
# 1            377  We need to put an end to fracking all over thi...
# 2            817  If I am elected president we will work togethe...
# 3            962  Secretary Clinton and I have differences of op...
# 4           1095  When we pass Medicare for all, everyone will h...
# 5           1478  You know what was called “socialized medicine”...
# 6            700  Join Bernie tomorrow for a rally in Palo Alto,...
# 7            392  RT @maryaliceparks: 7 days until California vo...
# 8            937  These are people adding their contributions be...
# 9           1405  I do think that we can fulfill the legacy of p...
#
#              tweet_id
# 0  738068724356370432
# 1  738054427341402114
# 2  738047938681704450
# 3  738043438021500928
# 4  738021814983491584
# 5  737997406587871232
# 6  737839921914740736
# 7  737824419205120000
# 8  737824126191046656
# 9  737807378691690496

# %%
# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2, 2))

# Pulls all of trumps tweet text's into one giant string
summaries = "".join(sanders_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(10)
# Out:
# [(u'https co', 107),
#  (u'of the', 12),
#  (u'we are', 10),
#  (u'this country', 10),
#  (u'the political', 10),
#  (u'to vote', 10),
#  (u'need to', 9),
#  (u'political revolution', 9),
#  (u'vote for', 9),
#  (u'puerto rico', 9)]

# %%
all_tweets = pd.DataFrame(trump_tweets + sanders_tweets)

# %%
all_tweets.head()
# Out:
#                        created_at           handle                mined_at  \
# 0  Wed Jun 01 13:17:58 +0000 2016  Donald J. Trump 2016-06-01 11:50:51.493
# 1  Tue May 31 23:18:28 +0000 2016  Donald J. Trump 2016-06-01 11:50:51.493
# 2  Tue May 31 23:17:33 +0000 2016  Donald J. Trump 2016-06-01 11:50:51.493
# 3  Tue May 31 23:14:42 +0000 2016  Donald J. Trump 2016-06-01 11:50:51.493
# 4  Tue May 31 22:51:56 +0000 2016  Donald J. Trump 2016-06-01 11:50:51.493
#
#    retweet_count                                               text  \
# 0           5799  So I raised/gave $5,600,000 for the veterans a...
# 1           4104  Congratulations to @seanhannity on his tremend...
# 2           5951  I am getting great credit for my press confere...
# 3           5859  Katie Couric, the third rate reporter, who has...
# 4           2151  I will be interviewed on @seanhannity tonight ...
#
#              tweet_id
# 0  737996614573260800
# 1  737785345459113985
# 2  737785114239864832
# 3  737784398515441664
# 4  737778668785766404

# %% [markdown]
# ## Preprocessing our Tweets
#
# In order to do classfication recall that we need a set of features.  Our features are literally what our presidential hopefulls say on Twitter.
#
# We will need to:
# - Vectorize input text data
# - Intialize a model (let's try Logistic regression)
# - Train / Predict / Cross Validate
# - Score / Evaluate

# %%
from sklearn.linear_model import LogisticRegression

# Preprocess our text data to Tfidf
tfv = TfidfVectorizer(lowercase=True, strip_accents='unicode')
X_all = tfv.fit_transform(all_tweets['text'])

# Setup logistic regression (or try another classification method here)
estimator = LogisticRegression()
estimator.fit(X_all, all_tweets['handle'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ## Check Prediction vs Random Sanders Tweet

# %%
# Prep our source as TfIdf vectors
source_test = [
    "Demanding that the wealthy and the powerful start paying their fair share of taxes that's exactly what the American people want.",
    "Crooked Hillary is spending tremendous amounts of Wall Street money on false ads against me. She is a very dishonest person!"
]

############
# NOTE:  Do not re-initialize the tfidf vectorizor or the feature space willbe overwritten and
# hence your transform will not match the number of features you trained your model on.
#
# This is why you only need to "transform" since you already "fit" previously
#
####

X_all = tfv.transform(source_test)

# Predict using previously trained logist regression `estimator`
estimator.predict_proba(X_all)
# Out:
# array([[ 0.64385463,  0.35614537],
#        [ 0.29054443,  0.70945557]])

# %% [markdown]
# ## Lab Time
#
# We would like you to perform an analysis using a proper cross validation.  Also, try classfication using other models.

# %% [markdown]
# ### 1. Implement the same analysis using more data.
#
# Experiment with using more data.  The API may not like that you are blowing through their limits so definitely be careful.  Try to grab only what you need 1x, then work on the copy of the objects that are returned.  Read the documents about rate limits and see if you can get enough without hitting the rate limit.  Are there any options availabl in the API to avoid such a problem?

# %% [markdown]
# ### 2. Implement K-Folds or test/train split.
#
# Double check that you are getting random data before moving forward.  What would happen if you over sample Trump more than Sanders?

# %% [markdown]
# ### 3. Mine more Tweets that aren't in your data set
# Or use the hold-out method to do a proper test.  Refer back to our advanced classification evaluation lesson if you need to.

# %% [markdown]
# ### 4. Check your classification report
# How's precision / recall of your model?

# %% [markdown]
# ### 5.  Change out your TFIDF vectorizer for CountVectorizer.
# How has this impacted your mode performance at all?

# %% [markdown]
# ### 6.  Implement a different classification method such as random forrests.
# Or pick one of your favorites

# %% [markdown]
# ### 7.  Try to remove stopwords from your text during your preprocessing step
#
# Then double check your classfication report.  Have things improved?

# %% [markdown]
# ### 8.  Try removing samples that have links or that are obviously just announcements or "noise" that doesn't appear to represent "True" tweets by the authors.

# %% [markdown]
# ### 9. What are some contrasting words or phrases that you can see between the ngrams for each author?

# %% [markdown]
# ### 10.  What do you think you can do to improve the scores further?

# %% [markdown]
# ### 11. **BONUS** Using TextBlob, add a sentiment feature to your dataset.

# %% [markdown]
# ### 12. BONUS BONUS Apply PCA to your text features
# Is this effective? (ie: we could talk about LDA here a little bit)

# %% [markdown]
# ## Closing
#
# - What where the most impactful changes that helped your models?
# - What do you think would happen if we had more Trump Tweets than Sanders?
# - What other projects might you think to apply these problems against?
