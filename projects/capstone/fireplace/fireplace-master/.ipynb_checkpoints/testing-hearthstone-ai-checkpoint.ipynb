# %%
#!/usr/bin/env python
import sys; sys.path.append("..")
from fireplace import cards
from fireplace.exceptions import GameOver
from fireplace.utils import play_full_game

def test_full_game():
    try:
        game = play_full_game()
    except GameOver:
        print("Game completed normally.")

def main(numgames):
    cards.db.initialize()
    for i in range(int(numgames)):
        test_full_game()

if __name__ == "__main__":
    main(1)
# Out:
# [fireplace.__init__]: Initializing card database
# [fireplace.__init__]: Merged 2253 cards
# [{'game_id': 37, 'player': 'player1', 'event_key': 'deck1', 'event_value': "['EX1_009', 'CS2_188', 'AT_110', 'CS2_171', 'OG_042', 'GVG_090', 'FP1_007', 'EX1_564', 'EX1_028', 'EX1_571', 'OG_174', 'EX1_583', 'EX1_155', 'GVG_108', 'GVG_064', 'OG_174', 'LOE_107', 'NEW1_025', 'AT_109', 'AT_124', 'GVG_030', 'EX1_178', 'FP1_027', 'EX1_162', 'AT_085', 'CS2_221', 'EX1_390', 'CS2_122', 'PRO_001', 'OG_200']", 'timestamp': '2016-06-05 15:14:26:458555'}]
# [{'game_id': 37, 'player': 'player1', 'event_key': 'deck_cost1', 'event_value': '3.7', 'timestamp': '2016-06-05 15:14:26:480563'}]
# [{'game_id': 37, 'player': 'player1', 'event_key': 'num_minions', 'event_value': '28', 'timestamp': '2016-06-05 15:14:26:497387'}]
# [{'game_id': 37, 'player': 'player1', 'event_key': 'num_spells', 'event_value': '2', 'timestamp': '2016-06-05 15:14:26:514345'}]
# [{'game_id': 37, 'player': 'player1', 'event_key': 'num_weapons', 'event_value': '0', 'timestamp': '2016-06-05 15:14:26:532285'}]
# [{'game_id': 37, 'player': 'player2', 'event_key': 'deck2', 'event_value': "['NEW1_037', 'GVG_116', 'EX1_002', 'CS2_187', 'AT_047', 'EX1_045', 'AT_103', 'EX1_170', 'AT_105', 'GVG_066', 'EX1_259', 'CS2_117', 'AT_111', 'EX1_096', 'EX1_564', 'EX1_103', 'EX1_575', 'EX1_564', 'CS2_120', 'GVG_068', 'EX1_563', 'CS2_187', 'GVG_084', 'CS2_045', 'EX1_298', 'OG_131', 'GVG_070', 'NEW1_030', 'OG_290', 'AT_122']", 'timestamp': '2016-06-05 15:14:26:556731'}]
# [{'game_id': 37, 'player': 'player2', 'event_key': 'deck_cost2', 'event_value': '4.56666666667', 'timestamp': '2016-06-05 15:14:26:574119'}]
# [{'game_id': 37, 'player': 'player2', 'event_key': 'num_minions', 'event_value': '28', 'timestamp': '2016-06-05 15:14:26:591545'}]
# [{'game_id': 37, 'player': 'player2', 'event_key': 'num_spells', 'event_value': '2', 'timestamp': '2016-06-05 15:14:26:609012'}]
# [{'game_id': 37, 'player': 'player2', 'event_key': 'num_weapons', 'event_value': '0', 'timestamp': '2016-06-05 15:14:26:625996'}]
# [{'game_id': 37, 'player': 'player1', 'event_key': 'player1_class', 'event_value': 'CardClass.DRUID', 'timestamp': '2016-06-05 15:14:26:643619'}]
# [fireplace.entity]: Setting up game Game(players=(Player(name='Player1', hero=None), Player(name='Player2', hero=None)))
# [fireplace.entity]: Tossing the coin... Player2 wins!
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Summon(<Summon.CARD>=<HeroPower ('Shapeshift')>)> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.actions]: Player1 summons [<HeroPower ('Shapeshift')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Summon(<Summon.CARD>=<Hero ('Malfurion Stormrage')>)> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.actions]: Player1 summons [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) shuffles their deck
# [fireplace.card]: <Minion ('Stonetusk Boar')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.card]: <Minion ('Abusive Sergeant')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.card]: <Minion ('Stranglethorn Tiger')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.card]: <Minion ("Y'Shaarj, Rage Unbound")> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Summon(<Summon.CARD>=<HeroPower ('Totemic Call')>)> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.actions]: Player2 summons [<HeroPower ('Totemic Call')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Summon(<Summon.CARD>=<Hero ('Thrall')>)> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.actions]: Player2 summons [<Hero ('Thrall')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player(name='Player2', hero=<Hero ('Thrall')>) shuffles their deck
# [fireplace.card]: <Minion ('Burly Rockjaw Trogg')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.card]: <Minion ('Draenei Totemcarver')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.card]: <Spell ('Rockbiter Weapon')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Entering mulligan phase
# [fireplace.utils]: Can mulligan [<Minion ('Stonetusk Boar')>, <Minion ('Abusive Sergeant')>, <Minion ('Stranglethorn Tiger')>, <Minion ("Y'Shaarj, Rage Unbound")>]
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Faceless Manipulator')>
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Spell ('Force of Nature')>
# [fireplace.card]: <Spell ('Force of Nature')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Eerie Statue')>
# [fireplace.card]: <Minion ('Eerie Statue')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.card]: <Minion ("Y'Shaarj, Rage Unbound")> moves from <Zone.HAND: 3> to <Zone.DECK: 2>
# [fireplace.card]: <Minion ('Stranglethorn Tiger')> moves from <Zone.HAND: 3> to <Zone.DECK: 2>
# [fireplace.card]: <Minion ('Stonetusk Boar')> moves from <Zone.HAND: 3> to <Zone.DECK: 2>
# [fireplace.entity]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) shuffles their deck
# [fireplace.utils]: Can mulligan [<Minion ('Burly Rockjaw Trogg')>, <Minion ('Draenei Totemcarver')>, <Spell ('Rockbiter Weapon')>]
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Emperor Cobra')>
# [fireplace.card]: <Minion ('Emperor Cobra')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.card]: <Minion ('Draenei Totemcarver')> moves from <Zone.HAND: 3> to <Zone.DECK: 2>
# [fireplace.entity]: Player(name='Player2', hero=<Hero ('Thrall')>) shuffles their deck
# [fireplace.entity]: Player1 gets The Coin (GAME_005)
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Give(<Give.CARD>='GAME_005')> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.actions]: Giving [<Spell ('The Coin')>] to Player1
# [fireplace.card]: <Spell ('The Coin')> moves from <Zone.SETASIDE: 6> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 begins turn 1
# [fireplace.entity]: Player2 is now at 1 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Faceless Manipulator')>
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [{'game_id': 37, 'player': 'player2', 'event_key': 'player2_class', 'event_value': 'CardClass.SHAMAN', 'timestamp': '2016-06-05 15:14:26:662080'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'first_player', 'event_value': 'Player2', 'timestamp': '2016-06-05 15:14:26:684101'}]
# Can mulligan [<Minion ('Stonetusk Boar')>, <Minion ('Abusive Sergeant')>, <Minion ('Stranglethorn Tiger')>, <Minion ("Y'Shaarj, Rage Unbound")>]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'cards_mulliganed', 'event_value': '[<Minion ("Y\'Shaarj, Rage Unbound")>, <Minion (\'Stranglethorn Tiger\')>, <Minion (\'Stonetusk Boar\')>]', 'timestamp': '2016-06-05 15:14:26:756846'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'cards_kept', 'event_value': "[<Minion ('Abusive Sergeant')>]", 'timestamp': '2016-06-05 15:14:26:773865'}]
# Can mulligan [<Minion ('Burly Rockjaw Trogg')>, <Minion ('Draenei Totemcarver')>, <Spell ('Rockbiter Weapon')>]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '1', 'timestamp': '2016-06-05 15:14:26:803767'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '1', 'timestamp': '2016-06-05 15:14:26:820789'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'cards_mulliganed', 'event_value': "[<Minion ('Draenei Totemcarver')>]", 'timestamp': '2016-06-05 15:14:26:841461'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'cards_kept', 'event_value': "[<Minion ('Burly Rockjaw Trogg')>, <Spell ('Rockbiter Weapon')>]", 'timestamp': '2016-06-05 15:14:26:857483'}]
# [fireplace.utils]: Playing <Spell ('Rockbiter Weapon')> on <Hero ('Thrall')>
# [fireplace.actions]: Player2 plays <Spell ('Rockbiter Weapon')> (target=<Hero ('Thrall')>, index=None)
# [fireplace.entity]: Player2 pays 1 mana
# [fireplace.card]: <Spell ('Rockbiter Weapon')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Spell ('Rockbiter Weapon')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=<Hero ('Thrall')>)> targeting [<Spell ('Rockbiter Weapon')>]
# [fireplace.actions]: Activating <Spell ('Rockbiter Weapon')> action targeting <Hero ('Thrall')>
# [fireplace.actions]: <Spell ('Rockbiter Weapon')> triggering <TargetedAction: Buff(<Buff.BUFF>='CS2_045e')> targeting [<Hero ('Thrall')>]
# [fireplace.entity]: Applying <Enchantment ('Rockbiter Weapon')> to <Hero ('Thrall')>
# [fireplace.card]: <Enchantment ('Rockbiter Weapon')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Hero ('Thrall')> attacks <Hero ('Malfurion Stormrage')>
# [fireplace.actions]: <Hero ('Thrall')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=3)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Hero ('Thrall')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=3)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Hero ('Thrall')> triggering <TargetedAction: Damage()> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 1
# [fireplace.entity]: Ending One-Turn effect: <Enchantment ('Rockbiter Weapon')>
# [fireplace.card]: <Enchantment ('Rockbiter Weapon')> moves from <Zone.PLAY: 1> to <Zone.REMOVEDFROMGAME: 5>
# [fireplace.entity]: Player1 begins turn 2
# [fireplace.entity]: Player1 is now at 1 mana crystals
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Nerubian Egg')>
# [fireplace.card]: <Minion ('Nerubian Egg')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Abusive Sergeant')> on None
# [fireplace.actions]: Player1 plays <Minion ('Abusive Sergeant')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 1 mana
# [fireplace.card]: <Minion ('Abusive Sergeant')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Abusive Sergeant')>]
# [fireplace.actions]: <Minion ('Abusive Sergeant')> has no target, action exits early
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Spell ('The Coin')> on None
# [fireplace.actions]: Player1 plays <Spell ('The Coin')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 0 mana
# [fireplace.card]: <Spell ('The Coin')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Spell ('The Coin')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Spell ('The Coin')>]
# [fireplace.actions]: Activating <Spell ('The Coin')> action targeting None
# [fireplace.actions]: <Spell ('The Coin')> triggering <TargetedAction: ManaThisTurn(<ManaThisTurn.AMOUNT>=1)> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 2
# Playing <Spell ('Rockbiter Weapon')> on <Hero ('Thrall')>
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '3.33333333333', 'timestamp': '2016-06-05 15:14:26:888517'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '1', 'timestamp': '2016-06-05 15:14:26:912045'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '1', 'timestamp': '2016-06-05 15:14:26:928065'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '27', 'timestamp': '2016-06-05 15:14:26:944585'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:26:960608'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '2', 'timestamp': '2016-06-05 15:14:26:980499'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '1', 'timestamp': '2016-06-05 15:14:26:997333'}]
# Playing <Minion ('Abusive Sergeant')> on None
# Playing <Spell ('The Coin')> on None
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '2.5', 'timestamp': '2016-06-05 15:14:27:038263'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '1', 'timestamp': '2016-06-05 15:14:27:055784'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '2', 'timestamp': '2016-06-05 15:14:27:071598'}]
# [fireplace.entity]: Player2 begins turn 3
# [fireplace.entity]: Player2 is now at 2 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Deathwing')>
# [fireplace.card]: <Minion ('Deathwing')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 uses hero power <HeroPower ('Totemic Call')> on None
# [fireplace.actions]: <HeroPower ('Totemic Call')> triggering <TargetedAction: Summon(<Summon.CARD>='CS2_051')> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.actions]: Player2 summons [<Minion ('Stoneclaw Totem')>]
# [fireplace.card]: <Minion ('Stoneclaw Totem')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 spends 2 mana on <HeroPower ('Totemic Call')>
# [fireplace.entity]: Player2 ends turn 3
# [fireplace.entity]: Player1 begins turn 4
# [fireplace.entity]: Player1 is now at 2 mana crystals
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '27', 'timestamp': '2016-06-05 15:14:27:088116'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:105637'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '3', 'timestamp': '2016-06-05 15:14:27:122409'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '2', 'timestamp': '2016-06-05 15:14:27:139840'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_power', 'event_value': 'target: None', 'timestamp': '2016-06-05 15:14:27:162719'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '5.5', 'timestamp': '2016-06-05 15:14:27:184745'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '2', 'timestamp': '2016-06-05 15:14:27:202027'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '3', 'timestamp': '2016-06-05 15:14:27:217046'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '27', 'timestamp': '2016-06-05 15:14:27:233975'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:249364'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '4', 'timestamp': '2016-06-05 15:14:27:266389'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '2', 'timestamp': '2016-06-05 15:14:27:282758'}]
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Ancient of War')>
# [fireplace.card]: <Minion ('Ancient of War')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Nerubian Egg')> on None
# [fireplace.actions]: Player1 plays <Minion ('Nerubian Egg')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 2 mana
# [fireplace.card]: <Minion ('Nerubian Egg')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Nerubian Egg')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Nerubian Egg')>]
# [fireplace.actions]: Activating <Minion ('Nerubian Egg')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Minion ('Abusive Sergeant')> attacks <Minion ('Stoneclaw Totem')>
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=2)> targeting [<Minion ('Stoneclaw Totem')>]
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=2)> targeting [<Minion ('Stoneclaw Totem')>]
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Damage()> targeting [<Minion ('Stoneclaw Totem')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: <Minion ('Stoneclaw Totem')> is removed from the field
# [fireplace.card]: <Minion ('Stoneclaw Totem')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Processing Death for <Minion ('Stoneclaw Totem')>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 4
# [fireplace.entity]: Player2 begins turn 5
# [fireplace.entity]: Player2 is now at 3 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Refreshment Vendor')>
# [fireplace.card]: <Minion ('Refreshment Vendor')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Emperor Cobra')> on None
# [fireplace.actions]: Player2 plays <Minion ('Emperor Cobra')> (target=None, index=None)
# [fireplace.entity]: Player2 pays 3 mana
# [fireplace.card]: <Minion ('Emperor Cobra')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: Activating <Minion ('Emperor Cobra')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 5
# Playing <Minion ('Nerubian Egg')> on None
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.0', 'timestamp': '2016-06-05 15:14:27:311292'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '2', 'timestamp': '2016-06-05 15:14:27:339054'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '4', 'timestamp': '2016-06-05 15:14:27:354374'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '27', 'timestamp': '2016-06-05 15:14:27:372402'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:387916'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '5', 'timestamp': '2016-06-05 15:14:27:405439'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '3', 'timestamp': '2016-06-05 15:14:27:421459'}]
# Playing <Minion ('Emperor Cobra')> on None
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '5.25', 'timestamp': '2016-06-05 15:14:27:452155'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '3', 'timestamp': '2016-06-05 15:14:27:468680'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '5', 'timestamp': '2016-06-05 15:14:27:484695'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '27', 'timestamp': '2016-06-05 15:14:27:500403'}]
# [fireplace.entity]: Player1 begins turn 6
# [fireplace.entity]: Player1 is now at 3 mana crystals
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Puddlestomper')>
# [fireplace.card]: <Minion ('Puddlestomper')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 uses hero power <HeroPower ('Shapeshift')> on None
# [fireplace.actions]: <HeroPower ('Shapeshift')> triggering <TargetedAction: Buff(<Buff.BUFF>='CS2_017o')> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Applying <Enchantment ('Claws')> to <Hero ('Malfurion Stormrage')>
# [fireplace.card]: <Enchantment ('Claws')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.actions]: <HeroPower ('Shapeshift')> triggering <TargetedAction: GainArmor(<GainArmor.AMOUNT>=1)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 spends 2 mana on <HeroPower ('Shapeshift')>
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> attacks <Minion ('Emperor Cobra')>
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Damage()> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=2)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=2)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Damage()> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: <Hero ('Malfurion Stormrage')> loses 1 armor instead of damage
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Minion ('Abusive Sergeant')> attacks <Minion ('Emperor Cobra')>
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=2)> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=2)> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: <Minion ('Abusive Sergeant')> triggering <TargetedAction: Damage()> targeting [<Minion ('Emperor Cobra')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=2)> targeting [<Minion ('Abusive Sergeant')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=2)> targeting [<Minion ('Abusive Sergeant')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Damage()> targeting [<Minion ('Abusive Sergeant')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggers off <TargetedAction: Damage()> from <Minion ('Emperor Cobra')>
# [fireplace.actions]: <Minion ('Emperor Cobra')> triggering <TargetedAction: Destroy()> targeting [<Minion ('Abusive Sergeant')>]
# [fireplace.actions]: <Minion ('Emperor Cobra')> marks <Minion ('Abusive Sergeant')> for imminent death
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: <Minion ('Abusive Sergeant')> is removed from the field
# [fireplace.card]: <Minion ('Abusive Sergeant')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: <Minion ('Emperor Cobra')> is removed from the field
# [fireplace.card]: <Minion ('Emperor Cobra')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Processing Death for <Minion ('Abusive Sergeant')>
# [fireplace.actions]: Processing Death for <Minion ('Emperor Cobra')>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 6
# [fireplace.entity]: Ending One-Turn effect: <Enchantment ('Claws')>
# [fireplace.card]: <Enchantment ('Claws')> moves from <Zone.PLAY: 1> to <Zone.REMOVEDFROMGAME: 5>
# [fireplace.entity]: Player2 begins turn 7
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:517427'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '6', 'timestamp': '2016-06-05 15:14:27:534449'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '3', 'timestamp': '2016-06-05 15:14:27:551832'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_power', 'event_value': 'target: None', 'timestamp': '2016-06-05 15:14:27:574268'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.6', 'timestamp': '2016-06-05 15:14:27:600292'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '2', 'timestamp': '2016-06-05 15:14:27:651767'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '6', 'timestamp': '2016-06-05 15:14:27:667790'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '26', 'timestamp': '2016-06-05 15:14:27:683805'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:699320'}]
# [fireplace.entity]: Player2 is now at 4 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('North Sea Kraken')>
# [fireplace.card]: <Minion ('North Sea Kraken')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Burly Rockjaw Trogg')> on None
# [fireplace.actions]: Player2 plays <Minion ('Burly Rockjaw Trogg')> (target=None, index=None)
# [fireplace.entity]: Player2 pays 4 mana
# [fireplace.card]: <Minion ('Burly Rockjaw Trogg')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Burly Rockjaw Trogg')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Burly Rockjaw Trogg')>]
# [fireplace.actions]: Activating <Minion ('Burly Rockjaw Trogg')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 7
# [fireplace.entity]: Player1 begins turn 8
# [fireplace.entity]: Player1 is now at 4 mana crystals
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Spiteful Smith')>
# [fireplace.card]: <Minion ('Spiteful Smith')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Eerie Statue')> on None
# [fireplace.actions]: Player1 plays <Minion ('Eerie Statue')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 4 mana
# [fireplace.card]: <Minion ('Eerie Statue')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Eerie Statue')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Eerie Statue')>]
# [fireplace.actions]: Activating <Minion ('Eerie Statue')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.aura]: Creating <AuraBuff <Minion ('Eerie Statue')> -> <Minion ('Eerie Statue')>>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 8
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '7', 'timestamp': '2016-06-05 15:14:27:718338'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '4', 'timestamp': '2016-06-05 15:14:27:736355'}]
# Playing <Minion ('Burly Rockjaw Trogg')> on None
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '6.75', 'timestamp': '2016-06-05 15:14:27:764351'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '4', 'timestamp': '2016-06-05 15:14:27:781870'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '7', 'timestamp': '2016-06-05 15:14:27:798387'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '26', 'timestamp': '2016-06-05 15:14:27:814837'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:830359'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '8', 'timestamp': '2016-06-05 15:14:27:848510'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '4', 'timestamp': '2016-06-05 15:14:27:867348'}]
# Playing <Minion ('Eerie Statue')> on None
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.2', 'timestamp': '2016-06-05 15:14:27:896880'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '4', 'timestamp': '2016-06-05 15:14:27:914290'}]
# [fireplace.entity]: Player2 begins turn 9
# [fireplace.entity]: Player2 is now at 5 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Ragnaros the Firelord')>
# [fireplace.card]: <Minion ('Ragnaros the Firelord')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 uses hero power <HeroPower ('Totemic Call')> on None
# [fireplace.actions]: <HeroPower ('Totemic Call')> triggering <TargetedAction: Summon(<Summon.CARD>='CS2_051')> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.actions]: Player2 summons [<Minion ('Stoneclaw Totem')>]
# [fireplace.card]: <Minion ('Stoneclaw Totem')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 spends 2 mana on <HeroPower ('Totemic Call')>
# [fireplace.actions]: <Minion ('Burly Rockjaw Trogg')> attacks <Minion ('Eerie Statue')>
# [fireplace.actions]: <Minion ('Burly Rockjaw Trogg')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=3)> targeting [<Minion ('Eerie Statue')>]
# [fireplace.actions]: <Minion ('Burly Rockjaw Trogg')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=3)> targeting [<Minion ('Eerie Statue')>]
# [fireplace.actions]: <Minion ('Burly Rockjaw Trogg')> triggering <TargetedAction: Damage()> targeting [<Minion ('Eerie Statue')>]
# [fireplace.actions]: <Minion ('Eerie Statue')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=7)> targeting [<Minion ('Burly Rockjaw Trogg')>]
# [fireplace.actions]: <Minion ('Eerie Statue')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=7)> targeting [<Minion ('Burly Rockjaw Trogg')>]
# [fireplace.actions]: <Minion ('Eerie Statue')> triggering <TargetedAction: Damage()> targeting [<Minion ('Burly Rockjaw Trogg')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: <Minion ('Burly Rockjaw Trogg')> is removed from the field
# [fireplace.card]: <Minion ('Burly Rockjaw Trogg')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Processing Death for <Minion ('Burly Rockjaw Trogg')>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 9
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '8', 'timestamp': '2016-06-05 15:14:27:930813'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '26', 'timestamp': '2016-06-05 15:14:27:946834'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:27:962351'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '9', 'timestamp': '2016-06-05 15:14:27:979371'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '5', 'timestamp': '2016-06-05 15:14:27:995892'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_power', 'event_value': 'target: None', 'timestamp': '2016-06-05 15:14:28:018422'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '7.2', 'timestamp': '2016-06-05 15:14:28:040450'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '2', 'timestamp': '2016-06-05 15:14:28:074545'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '9', 'timestamp': '2016-06-05 15:14:28:091061'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '26', 'timestamp': '2016-06-05 15:14:28:107804'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:28:124260'}]
# [fireplace.entity]: Player1 begins turn 10
# [fireplace.entity]: Player1 is now at 5 mana crystals
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Dire Wolf Alpha')>
# [fireplace.card]: <Minion ('Dire Wolf Alpha')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Faceless Manipulator')> on <Minion ('Eerie Statue')>
# [fireplace.actions]: Player1 plays <Minion ('Faceless Manipulator')> (target=<Minion ('Eerie Statue')>, index=None)
# [fireplace.entity]: Player1 pays 5 mana
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Faceless Manipulator')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=<Minion ('Eerie Statue')>)> targeting [<Minion ('Faceless Manipulator')>]
# [fireplace.actions]: Activating <Minion ('Faceless Manipulator')> action targeting <Minion ('Eerie Statue')>
# [fireplace.actions]: <Minion ('Faceless Manipulator')> triggering <TargetedAction: Morph(<Morph.CARD>=ExactCopy(<fireplace.dsl.selector.FuncSelector object at 0x000001B7EC345588>))> targeting [<Minion ('Faceless Manipulator')>]
# [fireplace.copy]: Creating a copy of <Minion ('Eerie Statue')>
# [fireplace.actions]: Morphing <Minion ('Faceless Manipulator')> into <Minion ('Eerie Statue')>
# [fireplace.card]: <Minion ('Eerie Statue')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: <Minion ('Faceless Manipulator')> is removed from the field
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.PLAY: 1> to <Zone.SETASIDE: 6>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.aura]: Creating <AuraBuff <Minion ('Eerie Statue')> -> <Minion ('Eerie Statue')>>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 10
# [fireplace.entity]: Player2 begins turn 11
# [fireplace.entity]: Player2 is now at 6 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ("Twin Emperor Vek'lor")>
# [fireplace.card]: <Minion ("Twin Emperor Vek'lor")> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Faceless Manipulator')> on <Minion ('Stoneclaw Totem')>
# [fireplace.actions]: Player2 plays <Minion ('Faceless Manipulator')> (target=<Minion ('Stoneclaw Totem')>, index=None)
# [fireplace.entity]: Player2 pays 5 mana
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Faceless Manipulator')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=<Minion ('Stoneclaw Totem')>)> targeting [<Minion ('Faceless Manipulator')>]
# [fireplace.actions]: Activating <Minion ('Faceless Manipulator')> action targeting <Minion ('Stoneclaw Totem')>
# [fireplace.actions]: <Minion ('Faceless Manipulator')> triggering <TargetedAction: Morph(<Morph.CARD>=ExactCopy(<fireplace.dsl.selector.FuncSelector object at 0x000001B7EC345588>))> targeting [<Minion ('Faceless Manipulator')>]
# [fireplace.copy]: Creating a copy of <Minion ('Stoneclaw Totem')>
# [fireplace.actions]: Morphing <Minion ('Faceless Manipulator')> into <Minion ('Stoneclaw Totem')>
# [fireplace.card]: <Minion ('Stoneclaw Totem')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: <Minion ('Faceless Manipulator')> is removed from the field
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.PLAY: 1> to <Zone.SETASIDE: 6>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 11
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '10', 'timestamp': '2016-06-05 15:14:28:142782'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '5', 'timestamp': '2016-06-05 15:14:28:159806'}]
# Playing <Minion ('Faceless Manipulator')> on <Minion ('Eerie Statue')>
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.2', 'timestamp': '2016-06-05 15:14:28:196577'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '5', 'timestamp': '2016-06-05 15:14:28:214463'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '10', 'timestamp': '2016-06-05 15:14:28:230486'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '26', 'timestamp': '2016-06-05 15:14:28:245506'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:28:260770'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '11', 'timestamp': '2016-06-05 15:14:28:278792'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '6', 'timestamp': '2016-06-05 15:14:28:295307'}]
# Playing <Minion ('Faceless Manipulator')> on <Minion ('Stoneclaw Totem')>
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '6.6', 'timestamp': '2016-06-05 15:14:28:331502'}]
# [fireplace.entity]: Player1 begins turn 12
# [fireplace.entity]: Player1 is now at 6 mana crystals
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Stonetusk Boar')>
# [fireplace.card]: <Minion ('Stonetusk Boar')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 uses hero power <HeroPower ('Shapeshift')> on None
# [fireplace.actions]: <HeroPower ('Shapeshift')> triggering <TargetedAction: Buff(<Buff.BUFF>='CS2_017o')> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Applying <Enchantment ('Claws')> to <Hero ('Malfurion Stormrage')>
# [fireplace.card]: <Enchantment ('Claws')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.actions]: <HeroPower ('Shapeshift')> triggering <TargetedAction: GainArmor(<GainArmor.AMOUNT>=1)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 spends 2 mana on <HeroPower ('Shapeshift')>
# [fireplace.utils]: Playing <Minion ('Puddlestomper')> on None
# [fireplace.actions]: Player1 plays <Minion ('Puddlestomper')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 2 mana
# [fireplace.card]: <Minion ('Puddlestomper')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Puddlestomper')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Puddlestomper')>]
# [fireplace.actions]: Activating <Minion ('Puddlestomper')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Dire Wolf Alpha')> on None
# [fireplace.actions]: Player1 plays <Minion ('Dire Wolf Alpha')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 2 mana
# [fireplace.card]: <Minion ('Dire Wolf Alpha')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Dire Wolf Alpha')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Dire Wolf Alpha')>]
# [fireplace.actions]: Activating <Minion ('Dire Wolf Alpha')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.aura]: Aura from <Minion ('Dire Wolf Alpha')> buffs <Minion ('Puddlestomper')> with 'EX1_162o'
# [fireplace.entity]: Applying <Enchantment ('Strength of the Pack')> to <Minion ('Puddlestomper')>
# [fireplace.card]: <Enchantment ('Strength of the Pack')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> attacks <Minion ('Stoneclaw Totem')>
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('Stoneclaw Totem')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('Stoneclaw Totem')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Damage()> targeting [<Minion ('Stoneclaw Totem')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 12
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '5', 'timestamp': '2016-06-05 15:14:28:350028'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '11', 'timestamp': '2016-06-05 15:14:28:366047'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '26', 'timestamp': '2016-06-05 15:14:28:382066'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '30', 'timestamp': '2016-06-05 15:14:28:399173'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '12', 'timestamp': '2016-06-05 15:14:28:416192'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '6', 'timestamp': '2016-06-05 15:14:28:433717'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_power', 'event_value': 'target: None', 'timestamp': '2016-06-05 15:14:28:455466'}]
# Playing <Minion ('Puddlestomper')> on None
# Playing <Minion ('Dire Wolf Alpha')> on None
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.0', 'timestamp': '2016-06-05 15:14:28:502023'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '6', 'timestamp': '2016-06-05 15:14:28:528548'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '12', 'timestamp': '2016-06-05 15:14:28:545568'}]
# [fireplace.entity]: Ending One-Turn effect: <Enchantment ('Claws')>
# [fireplace.card]: <Enchantment ('Claws')> moves from <Zone.PLAY: 1> to <Zone.REMOVEDFROMGAME: 5>
# [fireplace.entity]: Player2 begins turn 13
# [fireplace.entity]: Player2 is now at 7 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Faceless Manipulator')>
# [fireplace.card]: <Minion ('Faceless Manipulator')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Refreshment Vendor')> on None
# [fireplace.actions]: Player2 plays <Minion ('Refreshment Vendor')> (target=None, index=None)
# [fireplace.entity]: Player2 pays 4 mana
# [fireplace.card]: <Minion ('Refreshment Vendor')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Refreshment Vendor')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Refreshment Vendor')>]
# [fireplace.actions]: Activating <Minion ('Refreshment Vendor')> action targeting None
# [fireplace.actions]: <Minion ('Refreshment Vendor')> triggering <TargetedAction: Heal(<Heal.AMOUNT>=4)> targeting [<Hero ('Malfurion Stormrage')>, <Hero ('Thrall')>]
# [fireplace.actions]: <Minion ('Refreshment Vendor')> heals <Hero ('Malfurion Stormrage')> for 4
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 13
# ...
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('Booty Bay Bodyguard')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('Booty Bay Bodyguard')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Damage()> targeting [<Minion ('Booty Bay Bodyguard')>]
# [fireplace.actions]: <Minion ('Booty Bay Bodyguard')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=5)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('Booty Bay Bodyguard')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=5)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('Booty Bay Bodyguard')> triggering <TargetedAction: Damage()> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: <Hero ('Malfurion Stormrage')> loses 1 armor instead of damage
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Minion ('Stranglethorn Tiger')> attacks <Minion ('Booty Bay Bodyguard')>
# [fireplace.actions]: <Minion ('Stranglethorn Tiger')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=5)> targeting [<Minion ('Booty Bay Bodyguard')>]
# [fireplace.actions]: <Minion ('Stranglethorn Tiger')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=5)> targeting [<Minion ('Booty Bay Bodyguard')>]
# [fireplace.actions]: <Minion ('Stranglethorn Tiger')> triggering <TargetedAction: Damage()> targeting [<Minion ('Booty Bay Bodyguard')>]
# [fireplace.actions]: <Minion ('Booty Bay Bodyguard')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=5)> targeting [<Minion ('Stranglethorn Tiger')>]
# [fireplace.actions]: <Minion ('Booty Bay Bodyguard')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=5)> targeting [<Minion ('Stranglethorn Tiger')>]
# [fireplace.actions]: <Minion ('Booty Bay Bodyguard')> triggering <TargetedAction: Damage()> targeting [<Minion ('Stranglethorn Tiger')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: <Minion ('Stranglethorn Tiger')> is removed from the field
# [fireplace.card]: <Minion ('Stranglethorn Tiger')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: <Minion ('Booty Bay Bodyguard')> is removed from the field
# [fireplace.card]: <Minion ('Booty Bay Bodyguard')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Processing Death for <Minion ('Stranglethorn Tiger')>
# [fireplace.actions]: Processing Death for <Minion ('Booty Bay Bodyguard')>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 ends turn 28
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '27', 'timestamp': '2016-06-05 15:14:31:245477'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '8', 'timestamp': '2016-06-05 15:14:31:261497'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '19', 'timestamp': '2016-06-05 15:14:31:277514'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '28', 'timestamp': '2016-06-05 15:14:31:295535'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '10', 'timestamp': '2016-06-05 15:14:31:311597'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_power', 'event_value': 'target: None', 'timestamp': '2016-06-05 15:14:31:332626'}]
# Playing <Spell ('Uproot')> on None
# Playing <Minion ('Bloodsail Corsair')> on None
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.0', 'timestamp': '2016-06-05 15:14:31:378471'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'mana_used', 'event_value': '3', 'timestamp': '2016-06-05 15:14:31:424025'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_end', 'event_value': '28', 'timestamp': '2016-06-05 15:14:31:441041'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '4', 'timestamp': '2016-06-05 15:14:31:456059'}]
# [fireplace.entity]: Ending One-Turn effect: <Enchantment ('Claws')>
# [fireplace.card]: <Enchantment ('Claws')> moves from <Zone.PLAY: 1> to <Zone.REMOVEDFROMGAME: 5>
# [fireplace.entity]: Player2 begins turn 29
# [fireplace.entity]: Player2 is now at 10 mana crystals
# [fireplace.actions]: Player(name='Player2', hero=<Hero ('Thrall')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player2', hero=<Hero ('Thrall')>)]
# [fireplace.entity]: Player2 draws <Minion ('Salty Dog')>
# [fireplace.card]: <Minion ('Salty Dog')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Salty Dog')> on None
# [fireplace.actions]: Player2 plays <Minion ('Salty Dog')> (target=None, index=None)
# [fireplace.entity]: Player2 pays 5 mana
# [fireplace.card]: <Minion ('Salty Dog')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Salty Dog')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Salty Dog')>]
# [fireplace.actions]: Activating <Minion ('Salty Dog')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Minion ('Flying Machine')> attacks <Hero ('Malfurion Stormrage')>
# [fireplace.actions]: <Minion ('Flying Machine')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('Flying Machine')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('Flying Machine')> triggering <TargetedAction: Damage()> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Minion ('Searing Totem')> attacks <Minion ('Bloodsail Corsair')>
# [fireplace.actions]: <Minion ('Searing Totem')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('Bloodsail Corsair')>]
# [fireplace.actions]: <Minion ('Searing Totem')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('Bloodsail Corsair')>]
# [fireplace.actions]: <Minion ('Searing Totem')> triggering <TargetedAction: Damage()> targeting [<Minion ('Bloodsail Corsair')>]
# [fireplace.actions]: <Minion ('Bloodsail Corsair')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('Searing Totem')>]
# [fireplace.actions]: <Minion ('Bloodsail Corsair')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('Searing Totem')>]
# [fireplace.actions]: <Minion ('Bloodsail Corsair')> triggering <TargetedAction: Damage()> targeting [<Minion ('Searing Totem')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: <Minion ('Searing Totem')> is removed from the field
# [fireplace.card]: <Minion ('Searing Totem')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Processing Death for <Minion ('Searing Totem')>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Minion ('The Black Knight')> attacks <Minion ('Bloodsail Corsair')>
# [fireplace.actions]: <Minion ('The Black Knight')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=4)> targeting [<Minion ('Bloodsail Corsair')>]
# [fireplace.actions]: <Minion ('The Black Knight')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=4)> targeting [<Minion ('Bloodsail Corsair')>]
# [fireplace.actions]: <Minion ('The Black Knight')> triggering <TargetedAction: Damage()> targeting [<Minion ('Bloodsail Corsair')>]
# [fireplace.actions]: <Minion ('Bloodsail Corsair')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('The Black Knight')>]
# [fireplace.actions]: <Minion ('Bloodsail Corsair')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('The Black Knight')>]
# [fireplace.actions]: <Minion ('Bloodsail Corsair')> triggering <TargetedAction: Damage()> targeting [<Minion ('The Black Knight')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: <Minion ('Bloodsail Corsair')> is removed from the field
# [fireplace.card]: <Minion ('Bloodsail Corsair')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: Processing Death for <Minion ('Bloodsail Corsair')>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player2 ends turn 29
# [fireplace.entity]: Player1 begins turn 30
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '19', 'timestamp': '2016-06-05 15:14:31:472578'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_begins', 'event_value': '29', 'timestamp': '2016-06-05 15:14:31:491602'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'max_mana', 'event_value': '10', 'timestamp': '2016-06-05 15:14:31:508782'}]
# Playing <Minion ('Salty Dog')> on None
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'avg_hand_cost', 'event_value': '5.0', 'timestamp': '2016-06-05 15:14:31:537720'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'mana_used', 'event_value': '5', 'timestamp': '2016-06-05 15:14:31:594220'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'turn_end', 'event_value': '29', 'timestamp': '2016-06-05 15:14:31:610386'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_health', 'event_value': '3', 'timestamp': '2016-06-05 15:14:31:625816'}]
# [{'game_id': 37, 'player': 'Player2', 'event_key': 'hero_health', 'event_value': '19', 'timestamp': '2016-06-05 15:14:31:643840'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'turn_begins', 'event_value': '30', 'timestamp': '2016-06-05 15:14:31:661144'}]
# [fireplace.entity]: Player1 is now at 10 mana crystals
# [fireplace.actions]: Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>) triggering <TargetedAction: Draw()> targeting [Player(name='Player1', hero=<Hero ('Malfurion Stormrage')>)]
# [fireplace.entity]: Player1 draws <Minion ('Validated Doomsayer')>
# [fireplace.card]: <Minion ('Validated Doomsayer')> moves from <Zone.DECK: 2> to <Zone.HAND: 3>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 uses hero power <HeroPower ('Shapeshift')> on None
# [fireplace.actions]: <HeroPower ('Shapeshift')> triggering <TargetedAction: Buff(<Buff.BUFF>='CS2_017o')> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Applying <Enchantment ('Claws')> to <Hero ('Malfurion Stormrage')>
# [fireplace.card]: <Enchantment ('Claws')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.actions]: <HeroPower ('Shapeshift')> triggering <TargetedAction: GainArmor(<GainArmor.AMOUNT>=1)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Player1 spends 2 mana on <HeroPower ('Shapeshift')>
# [fireplace.utils]: Playing <Spell ('Uproot')> on None
# [fireplace.actions]: Player1 plays <Spell ('Uproot')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 0 mana
# [fireplace.card]: <Spell ('Uproot')> attempted a same-zone move in <Zone.PLAY: 1>
# [fireplace.entity]: Clearing buffs from <Spell ('Uproot')>
# [fireplace.card]: <Enchantment ('Uprooted')> moves from <Zone.PLAY: 1> to <Zone.REMOVEDFROMGAME: 5>
# [fireplace.actions]: <Spell ('Uproot')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Spell ('Uproot')>]
# [fireplace.actions]: Activating <Spell ('Uproot')> action targeting None
# [fireplace.actions]: <Spell ('Uproot')> triggering <TargetedAction: Buff(<Buff.BUFF>='EX1_178be')> targeting [<Spell ('Uproot')>]
# [fireplace.entity]: Applying <Enchantment ('Uprooted')> to <Spell ('Uproot')>
# [fireplace.card]: <Enchantment ('Uprooted')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Spell ('Tank Mode')> on None
# [fireplace.actions]: Player1 plays <Spell ('Tank Mode')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 0 mana
# [fireplace.card]: <Spell ('Tank Mode')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.actions]: <Spell ('Tank Mode')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Spell ('Tank Mode')>]
# [fireplace.actions]: Activating <Spell ('Tank Mode')> action targeting None
# [fireplace.actions]: <Spell ('Tank Mode')> triggering <TargetedAction: Buff(<Buff.BUFF>='GVG_030be')> targeting [<Spell ('Tank Mode')>]
# [fireplace.entity]: Applying <Enchantment ('Tank Mode')> to <Spell ('Tank Mode')>
# [fireplace.card]: <Enchantment ('Tank Mode')> moves from <Zone.SETASIDE: 6> to <Zone.PLAY: 1>
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.utils]: Playing <Minion ('Validated Doomsayer')> on None
# [fireplace.actions]: Player1 plays <Minion ('Validated Doomsayer')> (target=None, index=None)
# [fireplace.entity]: Player1 pays 5 mana
# [fireplace.card]: <Minion ('Validated Doomsayer')> moves from <Zone.HAND: 3> to <Zone.PLAY: 1>
# [fireplace.actions]: <Minion ('Validated Doomsayer')> triggering <TargetedAction: Battlecry(<Battlecry.TARGET>=None)> targeting [<Minion ('Validated Doomsayer')>]
# [fireplace.actions]: Activating <Minion ('Validated Doomsayer')> action targeting None
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> attacks <Minion ('The Black Knight')>
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=1)> targeting [<Minion ('The Black Knight')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=1)> targeting [<Minion ('The Black Knight')>]
# [fireplace.actions]: <Hero ('Malfurion Stormrage')> triggering <TargetedAction: Damage()> targeting [<Minion ('The Black Knight')>]
# [fireplace.actions]: <Minion ('The Black Knight')> triggering <TargetedAction: Hit(<Hit.AMOUNT>=4)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('The Black Knight')> triggering <TargetedAction: Predamage(<Predamage.AMOUNT>=4)> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.actions]: <Minion ('The Black Knight')> triggering <TargetedAction: Damage()> targeting [<Hero ('Malfurion Stormrage')>]
# [fireplace.entity]: <Hero ('Malfurion Stormrage')> loses 1 armor instead of damage
# [fireplace.entity]: Empty stack, refreshing auras and processing deaths
# [fireplace.card]: <HeroPower ('Shapeshift')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [fireplace.card]: <Hero ('Malfurion Stormrage')> moves from <Zone.PLAY: 1> to <Zone.GRAVEYARD: 4>
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'max_mana', 'event_value': '10', 'timestamp': '2016-06-05 15:14:31:678661'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'hero_power', 'event_value': 'target: None', 'timestamp': '2016-06-05 15:14:31:702130'}]
# Playing <Spell ('Uproot')> on None
# Playing <Spell ('Tank Mode')> on None
# Playing <Minion ('Validated Doomsayer')> on None
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'avg_hand_cost', 'event_value': '4.66666666667', 'timestamp': '2016-06-05 15:14:31:763501'}]
# [{'game_id': 37, 'player': 'Player1', 'event_key': 'lost', 'event_value': 'Zone.GRAVEYARD', 'timestamp': '2016-06-05 15:14:31:799535'}]
# Game completed normally.
