# %%
from sqlalchemy import create_engine

engine = create_engine('mysql://9cb054_testdb:paladinlol!@MYSQL5008.Smarterasp.net:3306/db_9cb054_testdb')

# engine = create_engine('mysql://dsi_student:9cb054_testdb@dsi.http://mysql5008.smarterasp.net/:3306/db_9cb054_testdb')

# %%
pd.read_sql("SHOW tables", con=engine)
# Out:
#    Tables_in_db_9cb054_testdb
# 0                        card
# 1                    carddraw
# 2                    cardturn
# 3                        deck
# 4                        game
# 5                        hand
# 6                minionattack
# 7                mulligancard
# 8                opponentdeck
# 9            opponentdeckcard
# 10                       turn
# 11                       user
# 12                   userdeck
# 13               userdeckcard

# %%
sql = """
SELECT * FROM game
ORDER BY GameID DESC
"""

train = pd.read_sql(sql, con=engine)
train.head()
# Out:
#    GameID GameUserName        GameUserClass   GameOpponent  \
# 0    1435        thall               Thrall  The Innkeeper
# 1    1434        thall               Thrall  The Innkeeper
# 2    1433      Jayford  Malfurion Stormrage  The Innkeeper
# 3    1432      Jayford               Guldan  The Innkeeper
# 4    1431      Jayford               Guldan  The Innkeeper
#
#      GameOpponentClass           GameStart             GameEnd     GameType  \
# 0  Malfurion Stormrage 2016-05-20 15:54:18 2016-05-20 15:54:18
# 1   Garrosh Hellscream 2016-05-20 09:42:59 2016-05-20 09:42:59  Constructed
# 2     Jaina Proudmoore 2016-05-19 23:01:56 2016-05-19 23:01:56
# 3    Valeera Sanguinar 2016-05-19 22:48:54 2016-05-19 22:48:54
# 4         Anduin Wrynn 2016-05-19 22:39:56 2016-05-19 22:39:56
#
#   GameRank Victory Coin                                         ReplayText
# 0        0             You draw  Argent Squire#You draw  Sir Finley M...
# 1        0             You draw  Argent Horserider#You draw  Flameton...
# 2        0             You draw  Disciple of CThun#You draw  Mire Kee...
# 3        0             You draw  Sea Giant#You draw  Darkshire Counci...
# 4        0             You draw  Leeroy Jenkins#You draw  Darkshire C...
