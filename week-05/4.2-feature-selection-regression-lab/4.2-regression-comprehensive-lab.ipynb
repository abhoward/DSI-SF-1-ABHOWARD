# %% [markdown]
# # Feature selection with regression lab
#
# You have been exploring feature selection, regularization, and evaluation metrics with classification this week (and last week).
#
# It's time to return to a regression problem.
#
# In this lab you will be working with a dataset on **reservoir levels in California**.
#
# ---
#
# ### Data summary
#
# The dataset contains these columns:
#
#     id : the reservoir string id
#     date : the string date of measurement
#     month : the month of measurement
#     year : the year of measurement
#     reservoir_volume : the current volume of the reservoir
#     dam : the dam that supplies water to the reservoir
#     lake : a lake associated with the reservoir
#     stream : a stream associated with the reservoir
#     capacity : the total capacity of the reservoir
#     elevation : the string for elevation of the reservoir
#     river_basin : string code for basin of the river associated with the reservoir
#     county : the string county code that the reservoir is in
#     hydrologic_area : another location string identifier
#     nearby_city : the city that the reservoir is located near
#     latitude : the exact latitude of the reservoir
#     longitude : the exact longitude of the reservoir
#     operator : the governmental organization that manages the reservoir
#
# ---
#
# ### Goal of the lab:
#
# Your primary goal is to **predict reservoir levels in 2015 using data from prior years**. Your primary evaluation metric will be **RMSE**, but feel free to try/use others as well.
#
# You have learned may useful skills to tackle this!
#
# - **Data munging/cleaning**
# - **EDA**
# - **Feature engineering**
# - **Feature selection**
# - **Regularization/gridsearching**
# - **Cross-validation**
#
# Use whatever you can to get the best predictive power! Godspeed.
#
# ---
#
# ### I WILL BE DOING THE LAB AT THE SAME TIME
#
# **You are competing with me in this lab to get a better RMSE.**
#
# YES, YES, I know it's "unfair" or whatever. However, I will be sharing my progress on my screen as I go through, so you have an advantage in that sense, since you can see what I'm doing as I go.
#
# #### WORK TOGETHER!!!
#
# Good Luck!
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
res = pd.read_csv('./dataset/reservoir_levels.csv')

# %%
res.head()
# Out:
#       date  month  year   id  reservoir_volume     dam         lake  \
# 0  2000-02      2  2000  APN            8891.0  Alpine  Alpine Lake
# 1  2000-03      3  2000  APN            8891.0  Alpine  Alpine Lake
# 2  2000-04      4  2000  APN            8891.0  Alpine  Alpine Lake
# 3  2000-05      5  2000  APN            8891.0  Alpine  Alpine Lake
# 4  2000-06      6  2000  APN            8250.0  Alpine  Alpine Lake
#
#             stream  capacity elevation  river_basin county    hydrologic_area  \
# 0  Lagunitas Creek      8900       654  COAST-MARIN  MARIN  SAN FRANCISCO BAY
# 1  Lagunitas Creek      8900       654  COAST-MARIN  MARIN  SAN FRANCISCO BAY
# 2  Lagunitas Creek      8900       654  COAST-MARIN  MARIN  SAN FRANCISCO BAY
# 3  Lagunitas Creek      8900       654  COAST-MARIN  MARIN  SAN FRANCISCO BAY
# 4  Lagunitas Creek      8900       654  COAST-MARIN  MARIN  SAN FRANCISCO BAY
#
#      nearby_city  latitude  longitude                        operator
# 0  STINSON BEACH     37.94   -122.637  Marin Municipal Water District
# 1  STINSON BEACH     37.94   -122.637  Marin Municipal Water District
# 2  STINSON BEACH     37.94   -122.637  Marin Municipal Water District
# 3  STINSON BEACH     37.94   -122.637  Marin Municipal Water District
# 4  STINSON BEACH     37.94   -122.637  Marin Municipal Water District

# %%
res.dtypes
# Out:
# date                 object
# month                 int64
# year                  int64
# id                   object
# reservoir_volume    float64
# dam                  object
# lake                 object
# stream               object
# capacity              int64
# elevation           float64
# river_basin          object
# county               object
# hydrologic_area      object
# nearby_city          object
# latitude            float64
# longitude           float64
# operator             object
# dtype: object

# %%
res.elevation = res.elevation.map(lambda x: x.rstrip('\' ft'))
res.elevation = pd.to_numeric(res.elevation, errors = 'coerce')
res.dropna(how = 'any')
# Out:
#           date  month  year   id  reservoir_volume     dam         lake  \
# 0      2000-02      2  2000  APN            8891.0  Alpine  Alpine Lake
# 1      2000-03      3  2000  APN            8891.0  Alpine  Alpine Lake
# 2      2000-04      4  2000  APN            8891.0  Alpine  Alpine Lake
# 3      2000-05      5  2000  APN            8891.0  Alpine  Alpine Lake
# 4      2000-06      6  2000  APN            8250.0  Alpine  Alpine Lake
# 5      2000-07      7  2000  APN            7295.0  Alpine  Alpine Lake
# 6      2000-08      8  2000  APN            6590.0  Alpine  Alpine Lake
# 7      2000-09      9  2000  APN            5918.0  Alpine  Alpine Lake
# 8      2000-10     10  2000  APN            5442.0  Alpine  Alpine Lake
# 9      2000-11     11  2000  APN            5507.0  Alpine  Alpine Lake
# 10     2000-12     12  2000  APN            5711.0  Alpine  Alpine Lake
# 11     2001-01      1  2001  APN            6739.0  Alpine  Alpine Lake
# 12     2001-02      2  2001  APN            8891.0  Alpine  Alpine Lake
# 13     2001-03      3  2001  APN            8891.0  Alpine  Alpine Lake
# 14     2001-04      4  2001  APN            8735.0  Alpine  Alpine Lake
# 15     2001-05      5  2001  APN            8185.0  Alpine  Alpine Lake
# 16     2001-06      6  2001  APN            7617.0  Alpine  Alpine Lake
# 17     2001-07      7  2001  APN            7323.0  Alpine  Alpine Lake
# 18     2001-08      8  2001  APN            6248.0  Alpine  Alpine Lake
# 19     2001-09      9  2001  APN            5831.0  Alpine  Alpine Lake
# 20     2001-10     10  2001  APN            4983.0  Alpine  Alpine Lake
# 21     2001-11     11  2001  APN            6110.0  Alpine  Alpine Lake
# 22     2001-12     12  2001  APN            3891.0  Alpine  Alpine Lake
# 23     2002-01      1  2002  APN            8891.0  Alpine  Alpine Lake
# 24     2002-02      2  2002  APN            8891.0  Alpine  Alpine Lake
# 25     2002-03      3  2002  APN            8891.0  Alpine  Alpine Lake
# 26     2002-04      4  2002  APN            8891.0  Alpine  Alpine Lake
# 27     2002-05      5  2002  APN            8643.0  Alpine  Alpine Lake
# 28     2002-06      6  2002  APN            7711.0  Alpine  Alpine Lake
# 29     2002-07      7  2002  APN            6874.0  Alpine  Alpine Lake
# ...        ...    ...   ...  ...               ...     ...          ...
# 34005  2012-08      8  2012  WSN           70800.0  Wishon  Lake Wishon
# 34006  2012-09      9  2012  WSN           66207.0  Wishon  Lake Wishon
# 34007  2012-10     10  2012  WSN           56028.0  Wishon  Lake Wishon
# 29     Marin Municipal Water District
# ...                               ...
# 34005          Pacific Gas & Electric
# 34006          Pacific Gas & Electric
# 34007          Pacific Gas & Electric
# 34008          Pacific Gas & Electric
# 34009          Pacific Gas & Electric
# 34010          Pacific Gas & Electric
# 34011          Pacific Gas & Electric
# 34012          Pacific Gas & Electric
# 34013          Pacific Gas & Electric
# 34014          Pacific Gas & Electric
# 34015          Pacific Gas & Electric
# 34016          Pacific Gas & Electric
# 34017          Pacific Gas & Electric
# 34019          Pacific Gas & Electric
# 34020          Pacific Gas & Electric
# 34021          Pacific Gas & Electric
# 34022          Pacific Gas & Electric
# 34023          Pacific Gas & Electric
# 34024          Pacific Gas & Electric
# 34025          Pacific Gas & Electric
# 34026          Pacific Gas & Electric
# 34027          Pacific Gas & Electric
# 34028          Pacific Gas & Electric
# 34029          Pacific Gas & Electric
# 34030          Pacific Gas & Electric
# 34031          Pacific Gas & Electric
# 34032          Pacific Gas & Electric
# 34033          Pacific Gas & Electric
# 34034          Pacific Gas & Electric
# 34035          Pacific Gas & Electric
#
# [30746 rows x 17 columns]

# %%
sns.heatmap(res.corr())

# %%
import patsy
import statsmodels.formula.api as smf

# %%
target = 'reservoir_volume'
cols = ['month', 'year', 'capacity', 'elevation', 'latitude', 'longitude']

# %%
res_train = res[res.year != 2015][['month', 'year', 'capacity', 'elevation', 'latitude', 'longitude', 'reservoir_volume']]
res_test = res[res.year == 2015][['month', 'year', 'capacity', 'elevation', 'latitude', 'longitude', 'reservoir_volume']]

# %%
res_train.ix[:, cols] = (res_train.ix[:, cols] - res_train.ix[:, cols].mean()) / res_train.ix[:, cols].std()
res_test.ix[:, cols] = (res_test.ix[:, cols] - res_test.ix[:, cols].mean()) / res_test.ix[:, cols].std()

# %%
formula = 'reservoir_volume ~ month + year + capacity + elevation + latitude + longitude'

# Ytrain, Xtrain = patsy.dmatrices(formula, data = res_train)
# Ytest, Xtest = patsy.dmatrices(formula, data = res_test)

logreg = smf.logit(formula, data = res_train)
# logreg_results = logreg.fit()
# print logreg_results.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-445f8329d2dc> in <module>()
#       4 # Ytest, Xtest = patsy.dmatrices(formula, data = res_test)
#       5
# ----> 6 logreg = smf.logit(formula, data = res_train)
#       7 # logreg_results = logreg.fit()
#       8 # print logreg_results.summary()
#
# /home/dsi-student/anaconda2/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#     148         kwargs.update({'missing_idx': missing_idx,
#     149                        'missing': missing})
# --> 150         mod = cls(endog, exog, *args, **kwargs)
#     151         mod.formula = formula
#     152
#
# /home/dsi-student/anaconda2/lib/python2.7/site-packages/statsmodels/discrete/discrete_model.pyc in __init__(self, endog, exog, **kwargs)
#     402         if (self.__class__.__name__ != 'MNLogit' and
#     403                 not np.all((self.endog >= 0) & (self.endog <= 1))):
# --> 404             raise ValueError("endog must be in the unit interval.")
#     405
#     406
#
# ValueError: endog must be in the unit interval.
