# %% [markdown]
# # Multi-table Datasets - ENRON Archive

# %% [markdown]
# ## 1. Data import
#
# Connect to the file 'assets/datasets/enron.db' using one of these methods:
#
# - sqlite3 python package
# - pandas.read_sql
# - SQLite Manager Firefox extension
#
# Take a look at the database and query the master table. How many Tables are there in the db?
#
# > Answer:
# There are 3 tables:
# - MessageBase
# - RecipientBase
# - EmployeeBase

# %%
import sqlite3
import pandas as pd
sqlite_db = '../../assets/datasets/enron.db'
conn = sqlite3.connect(sqlite_db) 
c = conn.cursor()

# %% [markdown]
# Query the `sqlite_master` table to retrieve the schema of the `EmployeeBase` table.
#
# 1. What fields are there?
# 1. What's the type of each of them?

# %%
employee_base.columns
# Out:
# Index([u'eid', u'name', u'department', u'longdepartment', u'title', u'gender',
#        u'seniority'],
#       dtype='object')

# %%
employee_base.dtypes
# Out:
# eid                int64
# name              object
# department        object
# longdepartment    object
# title             object
# gender            object
# seniority         object
# dtype: object

# %%
sql = """
SELECT * FROM sqlite_master
WHERE type = 'table'
"""

df = pd.read_sql(sql, con = conn)
df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table    MessageBase    MessageBase         3
# 1  table  RecipientBase  RecipientBase         5
# 2  table   EmployeeBase   EmployeeBase         2
#
#                                                  sql
# 0  CREATE TABLE MessageBase (\n    mid INTEGER,\n...
# 1  CREATE TABLE RecipientBase (\n    mid INTEGER,...
# 2  CREATE TABLE EmployeeBase (\n                 ...

# %%
sql1 = """
SELECT * FROM EmployeeBase"""

employee_base = pd.read_sql(sql1, con=conn)
employee_base
# Out:
#      eid               name department                     longdepartment  \
# 0      1        John Arnold   Forestry                  ENA Gas Financial
# 1      2        Harry Arora   Forestry                     ENA East Power
# 2      3      Robert Badeer   Forestry                     ENA West Power
# 3      4       Susan Bailey      Legal                          ENA Legal
# 4      5          Eric Bass   Forestry                      ENA Gas Texas
# 5      6   Don Baughman Jr.   Forestry                     ENA East Power
# 6      7         Sally Beck      Other                  Energy Operations
# 7      8      Robert Benson   Forestry                     ENA East Power
# 8      9         Lynn Blair      Other                                ETS
# 9     10  Sandra F. Brawner   Forestry                       ENA Gas East
# 10    11           Rick Buy   Forestry                              Enron
# 11    12     Larry Campbell      Other                                ETS
# 12    13  Larry F. Campbell      Other                     ENA East Power
# 13    14        Mike Carson   Forestry                     ENA East Power
# 14    15      Michelle Cash      Legal                          ENA Legal
# 15    16   Monika Causholli      Other           ENA West Power Real Time
# 16    17     Shelley Corman      Other                                ETS
# 17    18      Sean Crandall   Forestry                     ENA West Power
# 18    19      Martin Cuilla   Forestry                    ENA Gas Central
# 19    20      Jeff Dasovich      Legal  Regulatory and Government Affairs
# 20    21         Dana Davis      Other                                 NA
# 21    22         Clint Dean   Forestry                     ENA East Power
# 22    23         Craig Dean      Other           ENA West Power Real Time
# 23    24  David W. Delainey      Other                                EWS
# 24    25  James Derrick Jr.      Legal                              Enron
# 25    26   Stacy E. Dickson      Legal                          ENA Legal
# 26    27       Lindy Donoho      Other                                ETS
# 27    28        Tom Donohoe   Forestry                    ENA Gas Central
# 28    29      Chris Dorland   Forestry                     ENA East Power
# 29    30        Frank Ermis   Forestry                       ENA Gas West
# ..   ...                ...        ...                                ...
# 126  127       Geir Solberg      Other           ENA West Power Real Time
# 127  128    Steven P. South   Forestry                       ENA Gas West
# 128  129      Theresa Staab      Other                       ENA Gas West
# 129  130     Carol St Clair      Legal                          ENA Legal
# 130  131   James D. Steffes      Legal  Regulatory and Government Affairs
# 131  132   Joe Stepenovitch      Other                     ENA East Power
# 132  133      Chris Stokley      Other                     ENA West Power
# 133  134       Geoff Storey   Forestry                    ENA Gas Central
# 134  135  Fletcher J. Sturm   Forestry                     ENA East Power
# 135  136      Mike Swerzbin   Forestry                     ENA West Power
# 136  137         Kate Symes      Other           ENA West Power Real Time
# 137  138     Mark E. Taylor      Legal                          ENA Legal
# 138  139  Michael E. Taylor   Forestry                  Energy Operations
# 139  140      Jane M. Tholt   Forestry                       ENA Gas West
# 140  141     Paul D. Thomas      Other                     ENA East Power
# 141  142      Judy Townsend   Forestry                       ENA Gas East
# 142  143     Barry Tycholiz   Forestry                       ENA Gas West
# 143  144        Kim S. Ward   Forestry                       ENA Gas West
# 144  145    Kimberly Watson      Other                                ETS
# 145  146   V Charles Weldon      Other                      ENA Gas Texas
# 146  147       Greg Whalley      Other                                EWS
# 147  148    Stacey W. White      Other                  Energy Operations
# 148  149         Mark Whitt   Forestry                       ENA Gas West
# 149  150     Jason Williams      Other                    ENA Gas Central
# 150  151  Bill Williams III      Other           ENA West Power Real Time
# 151  152        Jason Wolfe      Other                       ENA Gas West
# 152  153       Paul Y’Barbo      Other                                ETS
# 153  154        Andy Zipper      Other                                EWS
# 154  155      John Zufferli      Other                                EWS
# 155  156   Phillip K. Allen   Forestry                       ENA Gas West
#
#                         title  gender seniority
# 0                  VP Trading    Male    Senior
# 1                  VP Trading    Male    Senior
# 2                 Mgr Trading    Male    Junior
# 3            Specialist Legal  Female    Junior
# 4                      Trader    Male    Junior
# 5                 Mgr Trading    Male    Junior
# 6                          VP  Female    Senior
# 7                 Dir Trading    Male    Senior
# 8                    Director  Female    Senior
# 9                 Dir Trading  Female    Senior
# 10                   VP & CRO    Male    Senior
# 11                 Specialist    Male    Junior
# 12                 Specialist    Male    Junior
# 13                Mgr Trading    Male    Junior
# 14                   Attorney  Female    Junior
# 15                    Analyst  Female    Junior
# 16                         VP  Female    Senior
# 17                Dir Trading    Male    Senior
# 18                Mgr Trading    Male    Junior
# 19                   Director    Male    Senior
# 20              Administrator  Female    Junior
# 21                Mgr Trading    Male    Junior
# 22                 Specialist    Male    Junior
# 23            President & CEO    Male    Senior
# 24              VP & Gen Cnsl    Male    Senior
# 25                       Cnsl  Female    Junior
# 26                   Employee  Female    Junior
# 27                Mgr Trading    Male    Junior
# 28                Mgr Trading    Male    Junior
# 29                Dir Trading    Male    Senior
# ..                        ...     ...       ...
# 126                   Analyst    Male    Junior
# 127               Dir Trading    Male    Senior
# 128                Specialist  Female    Junior
# 129  Director & Gen Cnsl Asst  Female    Senior
# 130  VP of Government Affairs    Male    Senior
# 131                Specialist    Male    Junior
# 132                Specialist    Male    Junior
# 133               Dir Trading    Male    Senior
# 134                VP Trading    Male    Senior
# 135                VP Trading    Male    Senior
# 136                  Employee  Female    Junior
# 137             VP & Gen Cnsl    Male    Senior
# 138                    Trader    Male    Junior
# 139               Dir Trading  Female    Senior
# 140                 Associate    Male    Junior
# 141               Mgr Trading  Female    Junior
# 142                VP Trading    Male    Senior
# 143               Mgr Trading  Female    Junior
# 144                  Director  Female    Senior
# 145                 Associate    Male    Junior
# 146           President & CEO    Male    Senior
# 147                  Director  Female    Senior
# 148                VP Trading    Male    Senior
# 149                Specialist    Male    Junior
# 150                   Analyst    Male    Junior
# 151                   Analyst    Male    Junior
# 152                  Director    Male    Senior
# 153        VP of Enron Online    Male    Senior
# 154        VP of Enron Canada    Male    Senior
# 155           Mng Dir Trading    Male    Senior
#
# [156 rows x 7 columns]

# %%
sql2 = """
SELECT * FROM MessageBase"""

message_base = pd.read_sql(sql2, con=conn)
message_base
# Out:
#          mid                                        filename   unix_time  \
# 0          1                                taylor-m/sent/11   910930020
# 1          2                                taylor-m/sent/17   911459940
# 2          3                                taylor-m/sent/18   911463840
# 3          4                                taylor-m/sent/23   911874180
# 4          5                                taylor-m/sent/27   912396120
# 5          6                                taylor-m/sent/31   912570420
# 6          7                                taylor-m/sent/33   912576240
# 7          8                                taylor-m/sent/40   912685080
# 8          9                                taylor-m/sent/41   912734100
# 9         10                                taylor-m/sent/44   913166040
# 10        11                                taylor-m/sent/45   913166220
# 11        12                                taylor-m/sent/52   913770180
# 12        13                                taylor-m/sent/57   913797300
# 13        14                                taylor-m/sent/62   913950120
# 14        15                       taylor-m/all_documents/73   914218140
# 15        16                                taylor-m/sent/71   914298240
# 16        17                     taylor-m/all_documents/8545   914997420
# 17        18                                taylor-m/sent/77   915416460
# 18        19                                taylor-m/sent/78   915423060
# 19        20                                taylor-m/sent/82   915698520
# 20        21                                taylor-m/sent/83   915698760
# 21        22                                taylor-m/sent/84   915699540
# 22        23                                taylor-m/sent/86   915766680
# 23        24                                taylor-m/sent/87   915783300
# 24        25                                taylor-m/sent/88   915785640
# 25        26                                taylor-m/sent/90   916104300
# 26        27                                taylor-m/sent/95   916198740
# 27        28                                taylor-m/sent/96   916209660
# 28        29                               taylor-m/sent/105   916363200
# 29        30                               taylor-m/sent/110   916384920
# ...      ...                                             ...         ...
# 21605  21606  germany-c/bankrupt/enron_compressor_services/8  1017754397
# 21606  21607                        germany-c/sent_items/410  1018254951
# 21607  21608                           germany-c/personal/16  1018298775
# 21608  21609            germany-c/bankrupt/transport/sonat/3  1018342581
# 21609  21610                           germany-c/personal/15  1018377766
# 21610  21611                           germany-c/personal/14  1018535392
# 21611  21612                        germany-c/sent_items/364  1018596219
# 21612  21613                        gang-l/deleted_items/387  1018855591
# 21613  21614                        germany-c/sent_items/350  1018856894
# 21614  21615                        germany-c/sent_items/290  1019550488
# 21615  21616                        germany-c/sent_items/285  1019557327
# 21616  21617          germany-c/bankrupt/transport/el_paso/6  1020157644
# 21617  21618          germany-c/bankrupt/transport/el_paso/4  1020161393
# 21618  21619          germany-c/bankrupt/transport/el_paso/2  1020260212
# 21619  21620                        germany-c/sent_items/202  1020348659
# 21620  21621                           parks-j/sent_items/78  1020348733
# 21621  21622                        germany-c/sent_items/201  1020348774
# 21622  21623                           germany-c/bankrupt/16  1020779689
# 21623  21624                           germany-c/bankrupt/14  1020926043
# 21624  21625                           germany-c/bankrupt/13  1020954843
# 21625  21626                           germany-c/bankrupt/12  1021030840
# 21626  21627    germany-c/bankrupt/transport/national_fuel/4  1021882185
# 21627  21628                            germany-c/personal/3  1022064217
# 21628  21629                              germany-c/inbox/66  1022531554
# 21629  21630                            germany-c/calendar/5  1022598148
# 21630  21631                              germany-c/inbox/49  1023708531
# 21631  21632                         germany-c/sent_items/74  1023873633
# 21632  21633                            germany-c/personal/1  1023873696
# 21633  21634                              germany-c/inbox/42  1023970571
# 21634  21635                              germany-c/inbox/23  1024666654
#
#                                                  subject  from_eid
# 0                                         Cd$ CME letter       138
# 1                                        Indemnification       138
# 2                                    Re: Indemnification       138
# 3                                 Re: Coral Energy, L.P.       138
# 4                              Bankruptcy Code revisions       138
# 5                               Re: Position Description       138
# 6                                                   Koch       138
# 7                                 Re: Time to Celebrate!       138
# 8                                   Re: Vacation Request       138
# 9                                       Re: Last Message       138
# 10                      Trading Documentation - Reminder       138
# 11                    Cancellation of Swap Group Meeting       138
# 12                                                  HL&P       138
# 13                              Re: Waste Managment Inc.       138
# 14                             Indemnification Agreement        15
# 15                         Re: ECT SA Legal Team Meeting       138
# 16     1998 Bonus & 1999 Merit Year-End Process Infor...        45
# 17                                                 Ormet       138
# 18                                                 Ormet       138
# 19                                 Friday telephone call       138
# 20                                               JEDI II       138
# 21                    Re: Master Swap Agreement for HL&P       138
# 22                                           Re: JEDI II       138
# 23                      Taking cash collateral in Canada       138
# 24      UK Courts vs. Arbitration for UK Swap Agreements       138
# 25                                               Houston       138
# 26     Re: UK Courts vs. Arbitration for UK Swap Agre...       138
# 27                                    Paralegal Position       138
# 28          Thursday - Option Investor Newsletter 2 of 2       138
# 29                       Financial Trading Documentation       138
# ...                                                  ...       ...
# 21605                                       FW: ADDENDUM        39
# 21606                                                Hey        39
# 21607                                            Re: Hey        94
# 21608                              RE: Sonat Park & Loan        39
# 21609                                            Re: Hey        94
# 21610                                            Re: Hey        94
# 21611                                RE: email addresses        39
# 21612                    FW: Tag's that EPE did not have       151
# 21613                                      Transco scoop        39
# 21614                  Midland Cogeneration for May 2002        39
# 21615                                                           39
# 21616  RE: EPNG Stipulation -- Rejection of ROFR Cont...        77
# 21617  RE: EPNG Stipulation -- Rejection of ROFR Cont...        77
# 21618  Re: URGENT  --  BTRC for the El Paso and Tenne...        77
# 21619                                           Activity        39
# 21620                                       RE: Activity        93
# 21621                                       RE: Activity        39
# 21622                             Master Termination Log        92
# 21623                             Master Termination Log        92
# 21624                             Master Termination Log        92
# 21625                             Information Tools Memo         4
# 21626  RE: Nation Fuel Gas Supply Corporation  ---  E...        77
# 21627   Sorry for the blank email...here's the real deal       118
# 21628                                         Re: Update        94
# 21629   Updated: Meeting regarding transport and storage        77
# 21630                                          NNG Deals        39
# 21631                                            Job Ops        39
# 21632                                        RE: Job Ops        57
# 21633                        Netting Agreement Materials         4
# 21634                             Master Termination Log        92
#
# [21635 rows x 5 columns]

# %%
sql3 = """
SELECT * FROM RecipientBase"""

recipient_base = pd.read_sql(sql3, con=conn)
recipient_base
# Out:
#          mid  rno  to_eid
# 0          1    1      59
# 1          2    1      15
# 2          3    1      15
# 3          4    1     109
# 4          4    2      49
# 5          4    3     120
# 6          4    4      59
# 7          5    1      45
# 8          5    2      53
# 9          6    1     113
# 10         7    1      59
# 11         8    1      59
# 12         9    1      49
# 13        10    1      59
# 14        11    1      59
# 15        12    1      49
# 16        12    2     120
# 17        12    3      59
# 18        13    1      59
# 19        14    1      59
# 20        15    1     138
# 21        16    1      58
# 22        16    2      26
# 23        16    3      45
# 24        16    4      53
# 25        17    1     138
# 26        17    2     113
# 27        17    3      53
# 28        18    1      53
# 29        19    1      59
# ...      ...  ...     ...
# 38358  21627    1      39
# 38359  21628    1      55
# 38360  21628    2      76
# 38361  21628    3      62
# 38362  21628    4     112
# 38363  21628    5      69
# 38364  21628    6     140
# 38365  21628    7      79
# 38366  21628    8     156
# 38367  21628    9      43
# 38368  21628   10     152
# 38369  21628   11      39
# 38370  21628   12      66
# 38371  21628   13      30
# 38372  21628   14     128
# 38373  21628   15      36
# 38374  21628   16       3
# 38375  21629    1      39
# 38376  21630    1      39
# 38377  21631    1     120
# 38378  21632    1      57
# 38379  21633    1      39
# 38380  21634    1      92
# 38381  21634    2     113
# 38382  21634    3      77
# 38383  21634    4      39
# 38384  21634    5     120
# 38385  21635    1      39
# 38386  21635    2     120
# 38387  21635    3       4
#
# [38388 rows x 3 columns]

# %% [markdown]
# 1. Print the first 5 rows of EmployeeBase table
# 1. Print the first 5 rows of MessageBase table
# 1. Print the first 5 rows of RecipientBase table
#
# **Hint**  use `SELECT` and `LIMIT`.

# %%
employee_base.head()
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
message_base.head()
# Out:
#    mid          filename  unix_time                    subject  from_eid
# 0    1  taylor-m/sent/11  910930020             Cd$ CME letter       138
# 1    2  taylor-m/sent/17  911459940            Indemnification       138
# 2    3  taylor-m/sent/18  911463840        Re: Indemnification       138
# 3    4  taylor-m/sent/23  911874180     Re: Coral Energy, L.P.       138
# 4    5  taylor-m/sent/27  912396120  Bankruptcy Code revisions       138

# %%
recipient_base.head()
# Out:
#    mid  rno  to_eid
# 0    1    1      59
# 1    2    1      15
# 2    3    1      15
# 3    4    1     109
# 4    4    2      49

# %% [markdown]
# Import each of the 3 tables to a Pandas Dataframes

# %% [markdown]
# ## 2. Data Exploration
#
# Use the 3 dataframes to answer the following questions:
#
# 1. How many employees are there in the company?
# - How many messages are there in the database?
# - Convert the timestamp column in the messages. When was the oldest message sent? And the newest?
# - Some messages are sent to more than one recipient. Group the messages by message_id and count the number of recepients. Then look at the distribution of recepient numbers.
#     - how many messages have only one recepient?
#     - how many messages have >= 5 recepients?
#     - what's the highest number of recepients?
#     - who sent the message with the highest number of recepients?
# - plot the distribution of recepient numbers using Bokeh

# %%
employee_base.head()
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
len(employee_base['name'].unique())
# Out:
# 156

# %%
message_base.head()
# Out:
#    mid          filename  unix_time                    subject  from_eid
# 0    1  taylor-m/sent/11  910930020             Cd$ CME letter       138
# 1    2  taylor-m/sent/17  911459940            Indemnification       138
# 2    3  taylor-m/sent/18  911463840        Re: Indemnification       138
# 3    4  taylor-m/sent/23  911874180     Re: Coral Energy, L.P.       138
# 4    5  taylor-m/sent/27  912396120  Bankruptcy Code revisions       138

# %%
message_base['mid'].count()
# Out:
# 21635

# %%
message_base['unix_time'] = pd.to_datetime(message_base['unix_time'],unit='s')

message_base.head()
# Out:
#    mid          filename           unix_time                    subject  \
# 0    1  taylor-m/sent/11 1998-11-13 04:07:00             Cd$ CME letter
# 1    2  taylor-m/sent/17 1998-11-19 07:19:00            Indemnification
# 2    3  taylor-m/sent/18 1998-11-19 08:24:00        Re: Indemnification
# 3    4  taylor-m/sent/23 1998-11-24 02:23:00     Re: Coral Energy, L.P.
# 4    5  taylor-m/sent/27 1998-11-30 03:22:00  Bankruptcy Code revisions
#
#    from_eid
# 0       138
# 1       138
# 2       138
# 3       138
# 4       138

# %% [markdown]
# Rescale to investigate the tail of the curve

# %%
print message_base['unix_time'].max()
print message_base['unix_time'].min()
# Out:
# 2002-06-21 13:37:34
# 1998-11-13 04:07:00

# %%
message_base.groupby(['from_eid'])['mid'].count()
# Out:
# from_eid
# 1       341
# 2        16
# 3        12
# 4       125
# 5       318
# 6        73
# 7       180
# 8         2
# 9       210
# 10       24
# 11       51
# 12        9
# 13        9
# 14       10
# 15       67
# 16        7
# 17      167
# 18       34
# 19       31
# 20     1597
# 21        1
# 22       10
# 23        5
# 24      290
# 25       41
# 26       95
# 27      150
# 28        7
# 29       92
# 30       15
#        ...
# 126      40
# 127      26
# 128      10
# 129      50
# 130     654
# 131     859
# 132       8
# 133      16
# 134      22
# 135      65
# 136      10
# 137     244
# 138     658
# 140      66
# 141      10
# 142      15
# 143     189
# 144     237
# 145     409
# 146      26
# 147      56
# 148      40
# 149     227
# 150       5
# 151     302
# 152      15
# 153      21
# 154      87
# 155      31
# 156     196
# Name: mid, dtype: int64

# %% [markdown]
# ## 3. Data Merging
#
# Use the pandas merge function to combine the information in the 3 dataframes to answer the following questions:
#
# 1. Are there more Men or Women employees?
# - How is gender distributed across departments?
# - Who is sending more emails? Men or Women?
# - What's the average number of emails sent by each gender?
# - Are there more Juniors or Seniors?
# - Who is sending more emails? Juniors or Seniors?
# - Which department is sending more emails? How does that relate with the number of employees in the department?
# - Who are the top 3 senders of emails? (people who sent out the most emails)

# %% [markdown]
# Also answer the following questions regarding received messages
#
# - Who is receiving more emails? Men or Women?
# - Who is receiving more emails? Juniors or Seniors?
# - Which department is receiving more emails? How does that relate with the number of employees in the department?
# - Who are the top 5 receivers of emails? (people who received the most emails)

# %% [markdown]
# Which employees sent the most 'mass' emails?

# %% [markdown]
# Keep exploring the dataset, which other questions would you ask?
#
# Work in pairs. Give each other a challenge and try to solve it.
